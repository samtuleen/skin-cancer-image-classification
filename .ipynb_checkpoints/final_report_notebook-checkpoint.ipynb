# %% [markdown]
# ![R.png](attachment:R.png)

# %% [markdown]
# # Skin Lesion Classification: Cancer or Not?
# **By: Sameeha Ramadhan**

# %% [markdown]
# # Introduction:

# %% [markdown]
# The goal of this project is to build a tool to correctly identify if whether or not a skin lesion is cancerous. The model will take in a picture of said lesion and calculate the probability that said lesion is benign (non-cancerous) or malignant (cancer).

# %% [markdown]
# ## Business Problem:

# %% [markdown]
# The use of such an algorithm would assist doctors and medical professionals in decreasing the time it takes to review and diagnose a patient as well as benefitting the patient by knowing sooner than later if cancer is present so that treatment could begin promptly. In addition, if a person is in doubt about a particular mole but hesitant to visit the doctor, this tool could give peace of mind (by diagnosing as benign) or encourage an appointment (should it output malignant).

# %% [markdown]
# # Import:

# %% [markdown]
# The following packages run the models:

# %%
import os
import pandas as pd
import numpy as np
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
color = sns.color_palette("flare", as_cmap=True)

from keras.preprocessing import image
from keras.models import Model, Sequential
from keras import layers
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation, MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf

#!pip install efficientnet <---installed

import efficientnet.keras as efn
from keras.applications.resnet50 import ResNet50
from keras import regularizers 
from keras.regularizers import l2

import keras
import keras.backend
from IPython.display import display

import cv2


from skimage.io import imread
from skimage.transform import resize
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

np.random.seed(20)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# I'll begin by first accessing the main directory and listing its contents:

# %%
main_dir = 'C:\\Users\\15164\\Desktop\\lesion\\'

# %%
data_directory = os.listdir('C:\\Users\\15164\\Desktop\\lesion\\')
print(data_directory)
# Out:
# ['test', 'train']

# %% [markdown]
# Next, I'll print the contents of each sub directory and the number of files each folder contains.
#
# **Note: this notebook was run on a sample of the original dataset, which contains over 28,000 images. I've previously ran my models over the entire dataset, however my kernel kept crashing after days of running models and I had to keep restarting. I am currently running a separate notebook in batches and will update when completed.**

# %%
for _set in ['train', 'test']:
    x_benign = len(os.listdir(main_dir + _set + '\\benign'))
    x_malignant = len(os.listdir(main_dir + _set + '\\malignant'))
    print('Set: {}, Benign Images: {}, Malignant Images: {}, Total: {}'.format(_set, x_benign,
                                                                                x_malignant, (x_benign + x_malignant)))
# Out:
# Set: train, Benign Images: 7200, Malignant Images: 7200, Total: 14400
# Set: test, Benign Images: 1800, Malignant Images: 1800, Total: 3600

# %% [markdown]
# A simple plot to confirm the images have successfully loaded, and then I will check the balance of the data:

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train', 'test']):
    set_path = main_dir+_set
    ax[i].imshow(plt.imread(set_path+'\\benign\\'+os.listdir(set_path+'\\benign\\')[1]), cmap='gist_gray')
    ax[i].set_title('Set: {}, Diagnosis: Benign'.format(_set))
    ax[i+2].imshow(plt.imread(set_path+'\\malignant\\'+os.listdir(set_path+'\\malignant\\')[1]), cmap='gist_gray')
    ax[i+2].set_title('Set: {}, Diagnosis: Malignant'.format(_set))

# %% [markdown]
# ## Checking Data Balance:

# %%
train_dir = os.path.join(main_dir, "train\\")
test_dir = os.path.join(main_dir, "test\\")

# %% [markdown]
# I'll create dataframes to plot the data and check its distribution:

# %%
#Train data:
train_df = []

benign_set = os.path.join(train_dir,'benign')
malignant_set = os.path.join(train_dir,'malignant')

#Image list:

benign_images = glob(benign_set+"/*.jpg") + glob(benign_set+"/*.jpeg") + glob(benign_set+"/*.png")
malignant_images = glob(malignant_set + "/*.jpg") + glob(malignant_set + "/*.jpeg") + glob(malignant_set + "/*.png")

#Benign scans are labeled 0:
for img in benign_images:
    train_df.append((img, 0))

#Malignant are labeled 1:
for img in malignant_images:
    train_df.append((img, 1))

#Creating a dataframe:
train_df = pd.DataFrame(train_df, columns=['Image', 'Diagnosis'], index=None)

# %%
#Test data:
test_df = []

benign_set = os.path.join(test_dir,'benign')
malignant_set = os.path.join(test_dir,'malignant')

#Image list:
benign_images = glob(benign_set+"/*.jpg") + glob(benign_set+"/*.jpeg") + glob(benign_set+"/*.png")
malignant_images = glob(malignant_set + "/*.jpg") + glob(malignant_set + "/*.jpeg") + glob(malignant_set + "/*.png")

#Benign scans are labeled 0:
for img in benign_images:
    test_df.append((img, 0))

#Malignant are labeled 1:
for img in malignant_images:
    test_df.append((img, 1))

#Create the dataframe:
test_df = pd.DataFrame(test_df, columns=['Image', 'Diagnosis'], index=None)

# %% [markdown]
# ## Plotting Binary Data:

# %%
def balance_check(data):
#'data': the dfs we've created
    image_count = data['Diagnosis'].value_counts()
    print('Counts:')
    print(image_count)
    
    plt.figure(figsize=(11,7))
    sns.barplot(x= image_count.index, y= image_count.values)
    plt.title('Plot of Diagnosis Balancing', fontsize= 14)
    plt.xlabel('Diagnosis', fontsize= 11)
    plt.ylabel('Image Count', fontsize= 11)
    plt.xticks(range(len(image_count.index)), ['Benign(0)', 'Malignant(1)'])
    plt.show()

# %%
balance_check(train_df)
# Out:
# Counts:
# 1    7200
# 0    7200
# Name: Diagnosis, dtype: int64

# %%
balance_check(test_df)
# Out:
# Counts:
# 1    1800
# 0    1800
# Name: Diagnosis, dtype: int64

# %% [markdown]
# ### Model Visualization Function:

# %% [markdown]
# Now I'll define a function that plots the accuracy and loss results of my CNN models for easy interpretation:

# %%
def model_performance(history):
    
    history_dict = history.history
    train_loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']#<--'val' here is for validation, and will be from the 'test' dataset
    train_accuracy = history_dict['accuracy']
    val_accuracy = history_dict['val_accuracy']

    fig, axis = plt.subplots(ncols=1, nrows=2, figsize=(8,8))
    
    #Plotting loss results:    
    epochs = range(1, len(val_loss_values) + 1) #epoch: the number of times the model will be fit on the training set.
    plot1 = sns.lineplot(ax=axis[0], x=epochs, y=train_loss_values, label='Train Loss')
    plot1 = sns.lineplot(ax=axis[0], x=epochs, y=val_loss_values, label='Val Loss')
    plot1.set(xlabel='Epochs', ylabel='Loss')
    plot1.axes.set_title('Model Loss', fontsize=18)
    plot1.grid(b=True, which='major', axis='y') #To show the grid lines or not
    
    plot2 = sns.lineplot(ax=axis[1], x=epochs, y=train_accuracy, label='Train Accuracy')
    plot2 = sns.lineplot(ax=axis[1], x=epochs, y=val_accuracy, label='Val Accuracy')
    plot2.set(xlabel='Epochs', ylabel='Accuracy')
    plot2.axes.set_title('Model Accuracy', fontsize=20)
    plot2.grid(b=True, which='major', axis='y')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 5 Block CNN Models: VGG16 Architecture

# %% [markdown]
# ## Image Augmentation:

# %%
def data_processing(img_dims, batch_size):
    train_data_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True)
    test_data_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True) #scaling the images 
    #to the same range [0,1]
    
    # This is fed to the network in the specified batch sizes and image dimensions
    train_generator = train_data_gen.flow_from_directory(
    directory=train_dir, 
    target_size=(img_dims, img_dims),  #Each image will be resized to this size
    batch_size=batch_size, #number of observations that are inputted into the model at one time
    class_mode='binary', 
    shuffle=True)

    test_generator = test_data_gen.flow_from_directory(
    directory=test_dir, 
    target_size=(img_dims, img_dims), 
    batch_size=batch_size, 
    class_mode='binary', 
    shuffle=False)
    
    # In order to plot the Confusion Matrix, I will be making predictions off of the test set in one batch size
    test_data = []
    test_labels = []

    for cond in ['/benign/', '/malignant/']:
        for img in (os.listdir(main_dir + 'test' + cond)):
            img = plt.imread(main_dir+'test'+cond+img)
            img = cv2.resize(img, (img_dims, img_dims))
            img = np.dstack([img, img, img])
            img = img.astype('float32') / 255
            if cond=='/benign/':
                label = 0
            elif cond=='/malignant/':
                label = 1
            test_data.append(img)
            test_labels.append(label)
        
    test_data = np.array(test_data)
    test_labels = np.array(test_labels)
    
    return train_generator, test_generator, test_data, test_labels

# %%
#Values for later use:
img_dims = 224
epochs = 30
batch_size = 20
train_generator, test_generator, test_data, test_labels = data_processing(img_dims, batch_size)
# Out:
# Found 14400 images belonging to 2 classes.
# Found 3600 images belonging to 2 classes.

# %% [markdown]
# ## Model 1:

# %% [markdown]
# Defining the model architecture and compiling (19):

# %%
inputs = Input(shape=(img_dims, img_dims, 3))

#1st Convolution
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#2nd Convolution
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model) #(15)
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#3rd Convolution
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#4th Convolution
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.2)(model)

#5th Convolution
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.2)(model)

# Fully Connected layer
model = Flatten()(model)
model = Dense(units=512, activation='relu')(model)
model = Dropout(rate=0.6)(model)
model = Dense(units=128, activation='relu')(model)
model = Dropout(rate=0.4)(model)
model = Dense(units=64, activation='relu')(model)
model = Dropout(rate=0.2)(model)

# Output layer
output = Dense(units=1, activation='sigmoid')(model) #<--Converting a real value into a interpretable probability

# Creating model and compiling
model = Model(inputs=inputs, outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(filepath='best_weights.hdf5', save_best_only=True, save_weights_only=True)
#hdf5 (Hierarchical Data Format) is to store the weights of the best performing epoch
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=2, mode='max') #<--Reduce learning rate 
#when the metric has stopped improving.
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=1, mode='min')

# %% [markdown]
# Fitting (training) the model:

# %%
hist = model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, 
           epochs=epochs, validation_data=test_generator, shuffle=True,
           validation_steps=test_generator.samples // batch_size, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/30
# 720/720 [==============================] - 906s 1s/step - loss: 0.4364 - accuracy: 0.8150 - val_loss: 0.3590 - val_accuracy: 0.8506
# Epoch 2/30
# 720/720 [==============================] - 871s 1s/step - loss: 0.3556 - accuracy: 0.8593 - val_loss: 1.1838 - val_accuracy: 0.5000
# Epoch 3/30
# 720/720 [==============================] - 868s 1s/step - loss: 0.3070 - accuracy: 0.8797 - val_loss: 0.4288 - val_accuracy: 0.8108
# Epoch 4/30
# 720/720 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8903
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 720/720 [==============================] - 870s 1s/step - loss: 0.2799 - accuracy: 0.8903 - val_loss: 0.4065 - val_accuracy: 0.8514
# Epoch 5/30
# 720/720 [==============================] - 858s 1s/step - loss: 0.2389 - accuracy: 0.9061 - val_loss: 0.2351 - val_accuracy: 0.8989
# Epoch 6/30
# 720/720 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9097
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 720/720 [==============================] - 857s 1s/step - loss: 0.2186 - accuracy: 0.9097 - val_loss: 0.3440 - val_accuracy: 0.8650
# Epoch 7/30
# 720/720 [==============================] - 848s 1s/step - loss: 0.2115 - accuracy: 0.9165 - val_loss: 0.2072 - val_accuracy: 0.9153
# Epoch 8/30
# 720/720 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9180
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 720/720 [==============================] - 856s 1s/step - loss: 0.2026 - accuracy: 0.9180 - val_loss: 0.2002 - val_accuracy: 0.9144
# Epoch 9/30
# 720/720 [==============================] - 845s 1s/step - loss: 0.1957 - accuracy: 0.9213 - val_loss: 0.2128 - val_accuracy: 0.9078
# Epoch 10/30
# 720/720 [==============================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9197
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 720/720 [==============================] - 870s 1s/step - loss: 0.1942 - accuracy: 0.9197 - val_loss: 0.1980 - val_accuracy: 0.9136
# Epoch 11/30
# 720/720 [==============================] - 865s 1s/step - loss: 0.1938 - accuracy: 0.9215 - val_loss: 0.1919 - val_accuracy: 0.9183
# Epoch 12/30
# 720/720 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9207
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 720/720 [==============================] - 863s 1s/step - loss: 0.1925 - accuracy: 0.9207 - val_loss: 0.1958 - val_accuracy: 0.9167
# Epoch 13/30
# 720/720 [==============================] - 843s 1s/step - loss: 0.1946 - accuracy: 0.9202 - val_loss: 0.1896 - val_accuracy: 0.9158
# Epoch 14/30
# 720/720 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9212
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 720/720 [==============================] - 851s 1s/step - loss: 0.1909 - accuracy: 0.9212 - val_loss: 0.1897 - val_accuracy: 0.9150
# Epoch 15/30
# 720/720 [==============================] - 839s 1s/step - loss: 0.1965 - accuracy: 0.9203 - val_loss: 0.1889 - val_accuracy: 0.9142
# Epoch 16/30
# 720/720 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9225
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 720/720 [==============================] - 843s 1s/step - loss: 0.1947 - accuracy: 0.9225 - val_loss: 0.1976 - val_accuracy: 0.9144
# Epoch 17/30
# 477/720 [==================>...........] - ETA: 4:19 - loss: 0.1948 - accuracy: 0.9215

# %% [markdown]
# Checking the perfomance:

# %%
model_performance(hist)

# %% [markdown]
# Now I'll calculate the confusion matrix:

# %%
preds = model.predict(test_generator)

accur = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()
#tp = true positive tn = true negative fp = false positive fn = false negative


print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(accur))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train Accuracy: {}'.format(np.round((hist.history["accuracy"][-1])*100, 2)))
# Out:
# CONFUSION MATRIX ------------------
# [[3851   32]
#  [ 396 1870]]
#
# TEST METRICS ----------------------
# Accuracy: 93.03951862091398%
# Precision: 98.31756046267087%
# Recall: 82.52427184466019%
# F1-score: 89.73128598848368
#
# TRAIN METRIC ----------------------
# Train Accuracy: 93.11

# %% [markdown]
# And finally visualize the matrix:

# %%
cm = pd.DataFrame(cm, index = ['Actual Benign', 'Actual Malignant'], columns = ['Predicted Benign', 'Predicted Malignant'])
plt.figure(figsize = (8,7))
labels = ['Benign', 'Malignant']
sns.heatmap(cm, cmap= "Blues", linecolor = 'black' , linewidth = 1, annot = True, fmt='')
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.show()

# %% [markdown]
# As shown in our matrix, our model produced semi-decent results with an 86% accuracy score. This means that out of 270 patients, 30 of them may be misdiagnosed as healthy when in fact they have a cancerous lesion. These numbers mean that 1 out of 9 will potentially not receive the care they need due to a wrong diagnosis, and while the numbers aren't too bad, when it comes to the health of a person these numbers are not ideal. And so, I will continue with a new model:

# %% [markdown]
# ## Model 2:

# %%
inputs = Input(shape=(img_dims, img_dims, 3))

#1st Convolution
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#2nd Convolution
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model) #(15)
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#3rd Convolution
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#4th Convolution
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.3)(model)#<--Updated dropout rate

#5th Convolution
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.3)(model)

# Fully Connected layer
model = Flatten()(model)
model = Dense(units=512, activation='relu')(model)
model = Dropout(rate=0.7)(model) #<--Updated dropout rate
model = Dense(units=128, activation='relu')(model)
model = Dropout(rate=0.5)(model) #<--Updated dropout rate
model = Dense(units=64, activation='relu')(model)
model = Dropout(rate=0.3)(model)#<--Updated dropout rate

# Output layer
output = Dense(units=1, activation='sigmoid')(model) #<--Converting a real value into a interpretable probability

# Creating model and compiling
model2 = Model(inputs=inputs, outputs=output)
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(filepath='best_weights2.hdf5', save_best_only=True, save_weights_only=True)
#hdf5 (Hierarchical Data Format) is to store the weights of the best performing epoch
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5, verbose=2, mode='max') #<--Reduce learning rate 
#when the metric has stopped improving.
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=20, mode='min')

# %% [markdown]
# I'll fit the model with 30 epochs and a larger batch size:

# %%
hist = model2.fit(train_generator, epochs=30, validation_data=test_generator,
                  shuffle=True, batch_size = 128, callbacks=[checkpoint, lr_reduce, early_stop])
# Out:
# Epoch 1/30
# 1230/1230 [==============================] - 1668s 1s/step - loss: 0.4091 - accuracy: 0.8219 - val_loss: 1.0371 - val_accuracy: 0.4010
# Epoch 2/30
# 1230/1230 [==============================] - 1667s 1s/step - loss: 0.3069 - accuracy: 0.8870 - val_loss: 0.3008 - val_accuracy: 0.8733
# Epoch 3/30
# 1230/1230 [==============================] - 1654s 1s/step - loss: 0.2796 - accuracy: 0.8989 - val_loss: 0.4198 - val_accuracy: 0.7964
# Epoch 4/30
# 1230/1230 [==============================] - 1653s 1s/step - loss: 0.2687 - accuracy: 0.9012 - val_loss: 0.5090 - val_accuracy: 0.7857
# Epoch 5/30
# 1230/1230 [==============================] - 1657s 1s/step - loss: 0.2555 - accuracy: 0.9054 - val_loss: 0.4176 - val_accuracy: 0.7548
# Epoch 6/30
# 1230/1230 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9096
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1230/1230 [==============================] - 1653s 1s/step - loss: 0.2457 - accuracy: 0.9096 - val_loss: 0.2588 - val_accuracy: 0.9106
# Epoch 7/30
# 1230/1230 [==============================] - 1655s 1s/step - loss: 0.2075 - accuracy: 0.9200 - val_loss: 0.1892 - val_accuracy: 0.9258
# Epoch 8/30
# 1230/1230 [==============================] - 1743s 1s/step - loss: 0.1978 - accuracy: 0.9240 - val_loss: 0.1865 - val_accuracy: 0.9237
# Epoch 9/30
# 1230/1230 [==============================] - 1683s 1s/step - loss: 0.1921 - accuracy: 0.9258 - val_loss: 0.1875 - val_accuracy: 0.9237
# Epoch 10/30
# 1230/1230 [==============================] - 1664s 1s/step - loss: 0.1900 - accuracy: 0.9247 - val_loss: 0.2049 - val_accuracy: 0.9229
# Epoch 11/30
# 1230/1230 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9262
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1230/1230 [==============================] - 1646s 1s/step - loss: 0.1878 - accuracy: 0.9262 - val_loss: 0.1966 - val_accuracy: 0.9206
# Epoch 12/30
# 1230/1230 [==============================] - 1656s 1s/step - loss: 0.1741 - accuracy: 0.9296 - val_loss: 0.1637 - val_accuracy: 0.9304
# Epoch 13/30
# 1230/1230 [==============================] - 1644s 1s/step - loss: 0.1722 - accuracy: 0.9308 - val_loss: 0.1658 - val_accuracy: 0.9278
# Epoch 14/30
# 1230/1230 [==============================] - 1648s 1s/step - loss: 0.1714 - accuracy: 0.9322 - val_loss: 0.1594 - val_accuracy: 0.9317
# Epoch 15/30
# 1230/1230 [==============================] - 1647s 1s/step - loss: 0.1675 - accuracy: 0.9325 - val_loss: 0.1608 - val_accuracy: 0.9325
# Epoch 16/30
# 1230/1230 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9324
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1230/1230 [==============================] - 1652s 1s/step - loss: 0.1650 - accuracy: 0.9324 - val_loss: 0.1837 - val_accuracy: 0.9215
# Epoch 17/30
# 1230/1230 [==============================] - 1643s 1s/step - loss: 0.1640 - accuracy: 0.9339 - val_loss: 0.1576 - val_accuracy: 0.9306
# Epoch 18/30
# 1230/1230 [==============================] - 1642s 1s/step - loss: 0.1630 - accuracy: 0.9338 - val_loss: 0.1571 - val_accuracy: 0.9317
# Epoch 19/30
# 1230/1230 [==============================] - 1633s 1s/step - loss: 0.1642 - accuracy: 0.9332 - val_loss: 0.1598 - val_accuracy: 0.9294
# Epoch 20/30
# 1230/1230 [==============================] - 1641s 1s/step - loss: 0.1611 - accuracy: 0.9338 - val_loss: 0.1573 - val_accuracy: 0.9312
# Epoch 21/30
# 1230/1230 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9333
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1230/1230 [==============================] - 1651s 1s/step - loss: 0.1613 - accuracy: 0.9333 - val_loss: 0.1536 - val_accuracy: 0.9330
# Epoch 22/30
# 1230/1230 [==============================] - 1649s 1s/step - loss: 0.1601 - accuracy: 0.9345 - val_loss: 0.1522 - val_accuracy: 0.9333
# Epoch 23/30
# 1230/1230 [==============================] - 1648s 1s/step - loss: 0.1604 - accuracy: 0.9343 - val_loss: 0.1516 - val_accuracy: 0.9325
# Epoch 24/30
# 1230/1230 [==============================] - 1648s 1s/step - loss: 0.1568 - accuracy: 0.9347 - val_loss: 0.1486 - val_accuracy: 0.9348
# Epoch 25/30
# 1230/1230 [==============================] - 1641s 1s/step - loss: 0.1584 - accuracy: 0.9349 - val_loss: 0.1500 - val_accuracy: 0.9327
# Epoch 26/30
# 1230/1230 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9353
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 1230/1230 [==============================] - 1641s 1s/step - loss: 0.1565 - accuracy: 0.9353 - val_loss: 0.1515 - val_accuracy: 0.9330
# Epoch 27/30
# 1230/1230 [==============================] - 1643s 1s/step - loss: 0.1588 - accuracy: 0.9347 - val_loss: 0.1491 - val_accuracy: 0.9343

# %% [markdown]
# I'll plot the performance:

# %%
model_performance(hist)

# %%
preds = model2.predict(test_generator)

accur = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()
#tp = true positive tn = true negative fp = false positive fn = false negative


print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(accur))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train Accuracy: {}'.format(np.round((hist.history["accuracy"][-1])*100, 2)))
# Out:
# CONFUSION MATRIX ------------------
# [[3875    8]
#  [ 401 1865]]
#
# TEST METRICS ----------------------
# Accuracy: 93.34851195316311%
# Precision: 99.572877736252%
# Recall: 82.30361871138571%
# F1-score: 90.11838608359508
#
# TRAIN METRIC ----------------------
# Train Accuracy: 93.47

# %%
cm = pd.DataFrame(cm, index = ['Actual Benign', 'Actual Malignant'], columns = ['Predicted Benign', 'Predicted Malignant'])
plt.figure(figsize = (8,7))
labels = ['Benign', 'Malignant']
sns.heatmap(cm, cmap= "Blues", linecolor = 'black' , linewidth = 1, annot = True, fmt='')
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.show()

# %% [markdown]
# So, our accuracy increased a bit from our last model (86% train and 85% test) however according to our confusion matrix, 1 out of 6 will be misdiagnosed as healthy while having cancer. This model has produced less favorable results than our previous one.

# %% [markdown]
# # Model 3: CNN w/No Augmentation:

# %%
from decimal import * #<--The decimal import provides functions for operating on numbers represented as decimals. (1)
from keras.preprocessing.image import  load_img
from keras.models import load_model 
import glob as glob

# %%
#Input values:
img_width=224
img_height=224
batch_size=64
input_shape=(img_width,img_width,3)

# %% [markdown]
# Next I'll define my classes and resize the images:

# %%
label = ['Benign','Malignant']

path = {}
x_train=[]
y_train=[]
classs=0
for img in label:
    path[img] = glob.glob(os.path.join(r'C:\\Users\\15164\\Desktop\\skin\\train\\', img, '*'))
    for image in path[img]:
        x_train.append(cv2.resize(cv2.imread(image),(img_width,img_width)))
        y_train.append(classs)
    classs=classs+1
    print(len(path[img]))
# Out:
# 15530
# 9063

# %%
path = {}
x_test=[]
y_test=[]
classs=0
for img in label:
    path[img] = glob.glob(os.path.join(r'C:\\Users\\15164\\Desktop\\skin\\val\\', img, '*'))
    for image in path[img]:
        x_test.append(cv2.resize(cv2.imread(image),(img_width,img_width)))
        y_test.append(classs)
    classs=classs+1
    print(len(path[img]))
# Out:
# 3883
# 2266

# %% [markdown]
# A quick check that images can be loaded:

# %%
plt.imshow(cv2.cvtColor(x_train[-1], cv2.COLOR_BGR2RGB)) #<--Converting BGR image to RGB since image processing 
#libraries have different pixel orderings. (2)
plt.title(label[y_train[-1]])
plt.show()

# %%
#Normalization
x_train =  np.array(x_train[:])
x_train =  x_train / 255

# %%
x_test = np.array(x_test[:])
x_test = x_test / 255

# %% [markdown]
# Now on to defining my model's architecture:

# %%
model3 = Sequential()

model3.add(Conv2D(32, (3,3), input_shape = (input_shape), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))


model3.add(Conv2D(32, (3,3), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))

model3.add(Conv2D(64, (3,3), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))

model3.add(Flatten())

model3.add(Dense(units = 4096, activation = 'relu'))
model3.add(Dense(units = 2048, activation = 'relu'))
model3.add(Dropout(0.2))

model3.add(Dense(units = len(label), activation = 'softmax'))


model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43264)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              177213440
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 185,636,834
# Trainable params: 185,636,834
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# I'll compile my model using sparse categorical crossentropy as my loss since my classes are mutually exclusive (meaning each sample belongs exactly to one class). (3) Also, due to the nature of my original dataset(very large and contains images that are very noisy with a lot of gradients) I'll optimize using 'Adam' because it is computationally efficient, has little memory requirements, the most suitable for problems that are large in terms of data and/or parameters, and is appropriate for problems with gradients. (4)

# %%
model3.compile(loss = 'sparse_categorical_crossentropy', optimizer ='adam', metrics = ['accuracy'])

# %% [markdown]
# And now, we train our model:

# %%
hist = model3.fit(x_train, np.array(y_train), epochs=70, steps_per_epoch= 170, batch_size=20)
# Out:
# Epoch 1/70
# 170/170 [==============================] - 254s 1s/step - loss: 1.1128 - accuracy: 0.6185
# Epoch 2/70
# 170/170 [==============================] - 245s 1s/step - loss: 0.5384 - accuracy: 0.7015
# Epoch 3/70
# 170/170 [==============================] - 245s 1s/step - loss: 0.5237 - accuracy: 0.7079
# Epoch 4/70
# 170/170 [==============================] - 244s 1s/step - loss: 0.4994 - accuracy: 0.7341
# Epoch 5/70
# 170/170 [==============================] - 247s 1s/step - loss: 0.5077 - accuracy: 0.7300
# Epoch 6/70
# 170/170 [==============================] - 247s 1s/step - loss: 0.4888 - accuracy: 0.7476
# Epoch 7/70
# 170/170 [==============================] - 248s 1s/step - loss: 0.4379 - accuracy: 0.7829
# Epoch 8/70
# 170/170 [==============================] - 247s 1s/step - loss: 0.4760 - accuracy: 0.7633
# Epoch 9/70
# 170/170 [==============================] - 255s 2s/step - loss: 0.4369 - accuracy: 0.7844
# Epoch 10/70
# 170/170 [==============================] - 272s 2s/step - loss: 0.4031 - accuracy: 0.8026
# Epoch 11/70
# 170/170 [==============================] - 301s 2s/step - loss: 0.4096 - accuracy: 0.8029
# Epoch 12/70
# 170/170 [==============================] - 308s 2s/step - loss: 0.4190 - accuracy: 0.8138
# Epoch 13/70
# 170/170 [==============================] - 323s 2s/step - loss: 0.3778 - accuracy: 0.8247
# Epoch 14/70
# 170/170 [==============================] - 282s 2s/step - loss: 0.3786 - accuracy: 0.8303
# Epoch 15/70
# 170/170 [==============================] - 284s 2s/step - loss: 0.3869 - accuracy: 0.8214
# Epoch 16/70
# 170/170 [==============================] - 331s 2s/step - loss: 0.3553 - accuracy: 0.8359
# Epoch 17/70
# 170/170 [==============================] - 321s 2s/step - loss: 0.3411 - accuracy: 0.8432
# Epoch 18/70
# 170/170 [==============================] - 396s 2s/step - loss: 0.3352 - accuracy: 0.8532
# Epoch 19/70
# 170/170 [==============================] - 451s 3s/step - loss: 0.3445 - accuracy: 0.8494
# Epoch 20/70
# 170/170 [==============================] - 407s 2s/step - loss: 0.3308 - accuracy: 0.8506
# Epoch 21/70
# 170/170 [==============================] - 522s 3s/step - loss: 0.3435 - accuracy: 0.8441
# Epoch 22/70
# 170/170 [==============================] - 516s 3s/step - loss: 0.3092 - accuracy: 0.8615
# Epoch 23/70
# 170/170 [==============================] - 425s 3s/step - loss: 0.3006 - accuracy: 0.8759
# Epoch 24/70
# 170/170 [==============================] - 363s 2s/step - loss: 0.3364 - accuracy: 0.8532
# Epoch 25/70
# 170/170 [==============================] - 499s 3s/step - loss: 0.2984 - accuracy: 0.8756
# Epoch 26/70
# 170/170 [==============================] - 635s 4s/step - loss: 0.3061 - accuracy: 0.8709
# Epoch 27/70
# 170/170 [==============================] - 578s 3s/step - loss: 0.3073 - accuracy: 0.8624
# Epoch 28/70
# 170/170 [==============================] - 764s 4s/step - loss: 0.2943 - accuracy: 0.8706
# Epoch 29/70
# 170/170 [==============================] - 689s 4s/step - loss: 0.2868 - accuracy: 0.8762
# Epoch 30/70
# 170/170 [==============================] - 409s 2s/step - loss: 0.2667 - accuracy: 0.8903
# Epoch 31/70
# 170/170 [==============================] - 396s 2s/step - loss: 0.2490 - accuracy: 0.8953
# Epoch 32/70
# 170/170 [==============================] - 519s 3s/step - loss: 0.2679 - accuracy: 0.8876
# Epoch 33/70
# 170/170 [==============================] - 692s 4s/step - loss: 0.2718 - accuracy: 0.8841
# Epoch 34/70
# 170/170 [==============================] - 674s 4s/step - loss: 0.2810 - accuracy: 0.8768
# Epoch 35/70
# 170/170 [==============================] - 677s 4s/step - loss: 0.2666 - accuracy: 0.8897
# Epoch 36/70
# 170/170 [==============================] - 805s 5s/step - loss: 0.2546 - accuracy: 0.8900
# Epoch 37/70
# 170/170 [==============================] - 378s 2s/step - loss: 0.2390 - accuracy: 0.8983
# Epoch 38/70
# 170/170 [==============================] - 494s 3s/step - loss: 0.2294 - accuracy: 0.9056
# Epoch 39/70
# 170/170 [==============================] - 463s 3s/step - loss: 0.2436 - accuracy: 0.8953
# Epoch 40/70
# 170/170 [==============================] - 656s 4s/step - loss: 0.2383 - accuracy: 0.9000
# Epoch 41/70
# 170/170 [==============================] - 645s 4s/step - loss: 0.2362 - accuracy: 0.9003
# Epoch 42/70
# 170/170 [==============================] - 12671s 75s/step - loss: 0.2371 - accuracy: 0.8988
# Epoch 43/70
# 170/170 [==============================] - 846s 5s/step - loss: 0.2406 - accuracy: 0.9012
# Epoch 44/70
# 170/170 [==============================] - 771s 5s/step - loss: 0.2155 - accuracy: 0.9122
# Epoch 45/70
# 170/170 [==============================] - 566s 3s/step - loss: 0.1854 - accuracy: 0.9247
# Epoch 46/70
# 170/170 [==============================] - 487s 3s/step - loss: 0.2171 - accuracy: 0.9074
# Epoch 47/70
# 170/170 [==============================] - 531s 3s/step - loss: 0.1969 - accuracy: 0.9188
# Epoch 48/70
# 170/170 [==============================] - 679s 4s/step - loss: 0.1965 - accuracy: 0.9191
# Epoch 49/70
# 170/170 [==============================] - 937s 6s/step - loss: 0.2140 - accuracy: 0.9088
# Epoch 50/70
# 170/170 [==============================] - 1038s 6s/step - loss: 0.2188 - accuracy: 0.9103
# Epoch 51/70
# 170/170 [==============================] - 590s 3s/step - loss: 0.2006 - accuracy: 0.9207
# Epoch 52/70
# 170/170 [==============================] - 350s 2s/step - loss: 0.1805 - accuracy: 0.9274
# Epoch 53/70
# 170/170 [==============================] - 695s 4s/step - loss: 0.1777 - accuracy: 0.9291
# Epoch 54/70
# 170/170 [==============================] - 1022s 6s/step - loss: 0.1712 - accuracy: 0.9306
# Epoch 55/70
# 170/170 [==============================] - 1355s 8s/step - loss: 0.1935 - accuracy: 0.9162
# Epoch 56/70
# 170/170 [==============================] - 993s 6s/step - loss: 0.2031 - accuracy: 0.9188
# Epoch 57/70
# 170/170 [==============================] - 857s 5s/step - loss: 0.1930 - accuracy: 0.9221
# Epoch 58/70
# 170/170 [==============================] - 798s 5s/step - loss: 0.1882 - accuracy: 0.9266
# Epoch 59/70
# 170/170 [==============================] - 547s 3s/step - loss: 0.1463 - accuracy: 0.9421
# Epoch 60/70
# 170/170 [==============================] - 537s 3s/step - loss: 0.1722 - accuracy: 0.9265
# Epoch 61/70
# 170/170 [==============================] - 883s 5s/step - loss: 0.1649 - accuracy: 0.9350
# Epoch 62/70
# 170/170 [==============================] - 1417s 8s/step - loss: 0.1604 - accuracy: 0.9329
# Epoch 63/70
# 170/170 [==============================] - 1562s 9s/step - loss: 0.1569 - accuracy: 0.9368
# Epoch 64/70
# 170/170 [==============================] - 1060s 6s/step - loss: 0.1772 - accuracy: 0.9247
# Epoch 65/70
# 170/170 [==============================] - 827s 5s/step - loss: 0.1703 - accuracy: 0.9279
# Epoch 66/70
# 170/170 [==============================] - 366s 2s/step - loss: 0.1264 - accuracy: 0.9472
# Epoch 67/70
# 170/170 [==============================] - 385s 2s/step - loss: 0.1421 - accuracy: 0.9418
# Epoch 68/70
# 170/170 [==============================] - 540s 3s/step - loss: 0.1504 - accuracy: 0.9300
# Epoch 69/70
# 170/170 [==============================] - 748s 4s/step - loss: 0.1637 - accuracy: 0.9365
# Epoch 70/70
# 170/170 [==============================] - 859s 5s/step - loss: 0.1429 - accuracy: 0.9447

# %% [markdown]
# ## Evaluate:

# %%
scores = model3.evaluate(x_test,np.array(y_test))
print("Accuracy = " + format(scores[1]*100, '.2f') + "%") #<-- "".2f" to print 2 decimal places as a string and float (5)
# Out:
# 193/193 [==============================] - 72s 373ms/step - loss: 0.4025 - accuracy: 0.8640
# Accuracy = 86.40%

# %%
fig, axis = plt.subplots(ncols=1, nrows=1, figsize=(10,5))
plot1= plt.plot(hist.history['accuracy'])
plot2=plt.plot(hist.history['loss'])
plot2=plt.title('Model Accuracy and Loss')
plot2=plt.ylabel('loss/accuracy')
plot2=plt.xlabel('epoch')
plot2=plt.legend(['accuracy', 'loss'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see from the accuracy score and the above accuracy/loss plot, our intial model performed well on our training set with a 95% accuracy. However, it's performed fairly decent on our test set, gaining an accuracy score of 86%.

# %% [markdown]
# # Model 4: EfficientNetB0

# %% [markdown]
# For my next model I've chosen to use EfficientNetB0, a pretrained image classification model that is optimized for state of the art accuracy while being smaller and faster. I've chosen this model because it comes from a family of models that have faster training speed and better parameter efficiency. [For more on EfficientNet models see references below]

# %%
#To free up memory space since our dataset is so large (the kernel kept crashing):
tf.keras.backend.clear_session()

# %%
s = 20
np.random.seed(s)
tf.random.set_seed(s)

# %%
#Resizing the images to a uniform size (a bit smaller than the usual 224 to save some memory space)
def resize_images(directory, resize):
    images = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for image_name in os.listdir(directory):
        PATH = os.path.join(directory, image_name)
        _, ftype = os.path.splitext(PATH)
        if ftype.endswith((".jpg", ".jpeg", ".png")):
            img = read(PATH)
            img = cv2.resize(img, (resize, resize))
            images.append(np.array(img)/255.) #<-- EfficientNet models require inputs to be float tensors of pixels
            #w/ values in the [0-255] range.
    return images

# %%
benign_train = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\train\\benign', 128))

# %%
malign_train = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\train\\malignant', 128))

# %%
benign_test = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\val\\benign', 128))

# %%
malign_test = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\val\\malignant', 128))

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merging
x_train = np.concatenate((benign_train, malign_train), axis = 0)
y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
x_test = np.concatenate((benign_test, malign_test), axis = 0)
y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffling train data
sh = np.arange(x_train.shape[0])
np.random.shuffle(sh)
x_train = x_train[sh]
y_train = y_train[sh]

# Shuffling test data
sh = np.arange(x_test.shape[0])
np.random.shuffle(sh)
x_test = x_test[sh]
y_test = y_test[sh]

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=s)

# %%
x_test.shape, x_val.shape, x_train.shape #<---Checking the split's success:
# Out:
# ((6149, 128, 128, 3), (4919, 128, 128, 3), (19674, 128, 128, 3))

# %%
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)
y_val = to_categorical(y_val, num_classes= 2)

# %%
# normalization 
x_train = x_train/255.
x_test = x_test/255.
x_val = x_val/255.

#Rechecking shape:
x_test.shape,  x_train.shape, x_val.shape,
# Out:
# ((6149, 128, 128, 3), (19674, 128, 128, 3), (4919, 128, 128, 3))

# %%
datagen = ImageDataGenerator(rotation_range=45, zoom_range = 0.1, width_shift_range=0.2, height_shift_range=0.2, 
                             horizontal_flip=True, vertical_flip=True)

# %%
eff_net = efn.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
model4=Sequential()
model4.add(eff_net)
model4.add(layers.GlobalAveragePooling2D())
model4.add(Dense(128, activation='relu'))
model4.add(BatchNormalization())
model4.add(Dense(2, activation='softmax'))

#Setting kernel regulizer: <--this is done to help lessen the chances of overfitting the model (6), (7)
alpha = 1e-3
for layer in model4.layers:
    if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.Dense):
        layer.add_loss(lambda: keras.regularizers.l2(alpha)(layer.kernel))
    if hasattr(layer, 'bias_regularizer') and layer.use_bias:
        layer.add_loss(lambda: keras.regularizers.l2(alpha)(layer.bias)) 


model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Functional) (None, 7, 7, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               163968
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,214,302
# Trainable params: 4,172,030
# Non-trainable params: 42,272
# _________________________________________________________________

# %% [markdown]
# Defining our callbacks (objects that perform actions at different times during training)(8)

# %%
#Slowing learning when the metric stops improving (9)
reduce_lr= ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=0, mode='max', min_delta=0.0001,
                             cooldown=0, min_lr=0) 

#Saving best weights (10)
checkpoint = ModelCheckpoint(filepath='best_weights2.hdf5', save_best_only=True, save_weights_only=True) 

#Stopping when the validation loss is increases too much (11)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=20, mode='min', verbose = 1)

optimizer= Adam(lr=0.0001)

# %%
# Shuffling train data again
sh = np.arange(x_train.shape[0])
np.random.shuffle(sh)
x_train = x_train[sh]
y_train = y_train[sh]

# Shuffling test data
#sh = np.arange(x_test.shape[0])
#np.random.shuffle(sh)
#x_test = x_test[sh]
#y_test = y_test[sh]

# Shuffling validation data to avoid overfitting the model: (12)
sh = np.arange(x_val.shape[0])
np.random.shuffle(sh)
x_val = x_val[sh]
y_val = y_val[sh]

# %%
# Using binary_crossentropy since this is a binary problem (13), (14)
model4.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])
hist = model4.fit(datagen.flow(x_train, y_train, batch_size=10), epochs=99, steps_per_epoch= 150,
                  validation_data=(x_val, y_val),callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 1/40
# 190/190 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8221WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("efficientnet-b0_input:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_1:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
# 190/190 [==============================] - 166s 874ms/step - loss: 0.4490 - accuracy: 0.8221 - val_loss: 5.4355 - val_accuracy: 0.5841
# Epoch 2/40
# 190/190 [==============================] - 165s 866ms/step - loss: 0.3896 - accuracy: 0.8605 - val_loss: 2.4965 - val_accuracy: 0.5387
# Epoch 3/40
# 190/190 [==============================] - 161s 850ms/step - loss: 0.3662 - accuracy: 0.8611 - val_loss: 0.8790 - val_accuracy: 0.6784
# Epoch 4/40
# 190/190 [==============================] - 161s 850ms/step - loss: 0.3546 - accuracy: 0.8606 - val_loss: 0.5557 - val_accuracy: 0.7707
# Epoch 5/40
# 190/190 [==============================] - 164s 863ms/step - loss: 0.3321 - accuracy: 0.8679 - val_loss: 0.4186 - val_accuracy: 0.8280
# Epoch 6/40
# 190/190 [==============================] - 159s 837ms/step - loss: 0.3070 - accuracy: 0.8737 - val_loss: 0.4992 - val_accuracy: 0.8012
# Epoch 7/40
# 190/190 [==============================] - 158s 833ms/step - loss: 0.3165 - accuracy: 0.8747 - val_loss: 0.4097 - val_accuracy: 0.8429
# Epoch 8/40
# 190/190 [==============================] - 158s 830ms/step - loss: 0.2990 - accuracy: 0.8811 - val_loss: 0.5208 - val_accuracy: 0.7811
# Epoch 9/40
# 190/190 [==============================] - 158s 831ms/step - loss: 0.2904 - accuracy: 0.8874 - val_loss: 0.2788 - val_accuracy: 0.8918
# Epoch 10/40
# 190/190 [==============================] - 161s 845ms/step - loss: 0.2716 - accuracy: 0.9011 - val_loss: 0.3831 - val_accuracy: 0.8498
# Epoch 11/40
# 190/190 [==============================] - 158s 833ms/step - loss: 0.2735 - accuracy: 0.8884 - val_loss: 0.2589 - val_accuracy: 0.9071
# Epoch 12/40
# 190/190 [==============================] - 158s 830ms/step - loss: 0.2539 - accuracy: 0.8963 - val_loss: 0.3082 - val_accuracy: 0.8892
# Epoch 13/40
# 190/190 [==============================] - 157s 829ms/step - loss: 0.2718 - accuracy: 0.8921 - val_loss: 0.3371 - val_accuracy: 0.8782
# Epoch 14/40
# 190/190 [==============================] - 154s 812ms/step - loss: 0.2494 - accuracy: 0.9042 - val_loss: 0.4428 - val_accuracy: 0.8266
# Epoch 15/40
# 190/190 [==============================] - 156s 821ms/step - loss: 0.2917 - accuracy: 0.8947 - val_loss: 0.3544 - val_accuracy: 0.8559
# Epoch 16/40
# 190/190 [==============================] - 156s 823ms/step - loss: 0.2545 - accuracy: 0.9000 - val_loss: 0.4428 - val_accuracy: 0.8146
# Epoch 17/40
# 190/190 [==============================] - 158s 833ms/step - loss: 0.2659 - accuracy: 0.8970 - val_loss: 0.3010 - val_accuracy: 0.8868
# Epoch 18/40
# 190/190 [==============================] - 157s 828ms/step - loss: 0.2298 - accuracy: 0.9105 - val_loss: 0.3194 - val_accuracy: 0.8792
# Epoch 19/40
# 190/190 [==============================] - 157s 825ms/step - loss: 0.2296 - accuracy: 0.9100 - val_loss: 0.2876 - val_accuracy: 0.8921
# Epoch 20/40
# 190/190 [==============================] - 155s 818ms/step - loss: 0.2415 - accuracy: 0.9016 - val_loss: 0.3076 - val_accuracy: 0.8853
# Epoch 21/40
# 190/190 [==============================] - 157s 824ms/step - loss: 0.2238 - accuracy: 0.9179 - val_loss: 0.2879 - val_accuracy: 0.8931
# Epoch 22/40
# 190/190 [==============================] - 157s 824ms/step - loss: 0.2226 - accuracy: 0.9195 - val_loss: 0.3107 - val_accuracy: 0.8835
# Epoch 23/40
# 190/190 [==============================] - 157s 826ms/step - loss: 0.2095 - accuracy: 0.9153 - val_loss: 0.2976 - val_accuracy: 0.8888
# Epoch 24/40
# 190/190 [==============================] - 157s 825ms/step - loss: 0.2575 - accuracy: 0.8968 - val_loss: 0.3062 - val_accuracy: 0.8837
# Epoch 25/40
# 190/190 [==============================] - 156s 823ms/step - loss: 0.2222 - accuracy: 0.9163 - val_loss: 0.3030 - val_accuracy: 0.8866
# Epoch 26/40
# 190/190 [==============================] - 156s 820ms/step - loss: 0.2249 - accuracy: 0.9153 - val_loss: 0.3028 - val_accuracy: 0.8876
# Epoch 27/40
# 190/190 [==============================] - 158s 830ms/step - loss: 0.2201 - accuracy: 0.9137 - val_loss: 0.3086 - val_accuracy: 0.8849
# Epoch 28/40
# 190/190 [==============================] - 157s 826ms/step - loss: 0.2347 - accuracy: 0.9111 - val_loss: 0.3337 - val_accuracy: 0.8733
# Epoch 29/40
# 190/190 [==============================] - 157s 826ms/step - loss: 0.2301 - accuracy: 0.9084 - val_loss: 0.3118 - val_accuracy: 0.8843
# Epoch 00029: early stopping

# %% [markdown]
# I'll use my previously defined function to plot the loss and accuracy for both the training and validation sets:

# %%
model_performance(hist)

# %% [markdown]
# And a quick evaluation of each set:

# %%
model4.evaluate(x_train, y_train)
# Out:
# 615/615 [==============================] - 209s 340ms/step - loss: 0.2844 - accuracy: 0.8893
# [0.2843962013721466, 0.8892955183982849]

# %%
model4.evaluate(x_val, y_val)
# Out:
# 154/154 [==============================] - 54s 353ms/step - loss: 0.3118 - accuracy: 0.8843
# [0.31175506114959717, 0.8843261003494263]

# %%
model4.evaluate(x_test, y_test)
# Out:
# 193/193 [==============================] - 66s 343ms/step - loss: 0.3007 - accuracy: 0.8818
# [0.3007075786590576, 0.8817694187164307]

# %% [markdown]
# As we can see, our model is not overfit and it produced decent results as seen above: **88.9% accuracy on our training set, 88.4% for our validation, and 88% on our test set.**

# %% [markdown]
# # Model 5: ResNet50:

# %% [markdown]
# I will now build my final model using ResNet50 (16), a pretrained image classification model that consists of a 50 layer deep convolutional network. I've chosen this model because since my dataset is large and this particular model has been trained on thousands of images in very deep layers, I am hopeful this will achieve optimal accuracy results. (17)

# %% [markdown]
# First, I'll define my image size, the number of epochs, classes, batch size and my data augmentation.

# %%
height, width = (224, 224)
epochs = 30 
classes_name = ('benign','malignant')
batch_size = 34
imgdatagen = ImageDataGenerator(rescale = 1./255,
                                     rotation_range=45,  
                                     zoom_range = 0.2, 
                                     width_shift_range=0.2,  
                                     height_shift_range=0.2)

# %% [markdown]
# Now I'll augment:

# %%
train_aug = imgdatagen.flow_from_directory(train_dir, target_size = (height, width), 
                classes = classes_name,  batch_size = batch_size)

val_aug = imgdatagen.flow_from_directory(test_dir, target_size = (height, width), 
                classes = classes_name, batch_size = batch_size, shuffle=False)
# Out:
# Found 24593 images belonging to 2 classes.
# Found 6149 images belonging to 2 classes.

# %% [markdown]
# Next I'll define my model's architecture by not including the top. This means I'll remove the last dense layers to allow the features of my model to be extracted. Then I will compile and finally, fit my model.

# %%
base_model= ResNet50(include_top=False, weights="imagenet", input_shape=(height, width,3))
model5= Sequential()
model5.add(base_model)
model5.add(Conv2D(64, (3, 3), activation = 'relu'))
model5.add(Dropout(0.2))
model5.add(Conv2D(64, (3, 3), activation = 'relu'))
model5.add(MaxPooling2D(pool_size = (2, 2)))
model5.add(Dropout(0.2))
model5.add(Flatten())
model5.add(Dense(512,activation='relu'))
model5.add(Dense(256,activation='relu'))
model5.add(Dropout(0.2))
model5.add(Dense(128,activation='relu'))
model5.add(Dense(64,activation='relu'))
model5.add(Dense(32,activation='relu'))
model5.add(Dense(16,activation='relu'))
model5.add(Dense(8,activation='relu'))
model5.add(Dense(2, activation='softmax'))
model5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          1179712
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               33280
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 25,012,874
# Trainable params: 24,959,754
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model5.compile(optimizer=Adam(lr=0.00001),loss="categorical_crossentropy",metrics=["accuracy"])

# %%
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=.5, min_lr=0.00001) 
hist = model5.fit(train_aug, steps_per_epoch=150, batch_size=10,
                  validation_data=val_aug, verbose=1, validation_steps=150,
                  epochs=epochs, callbacks=[lr_reduce])
# Out:
# Epoch 1/30
# 150/150 [==============================] - 2260s 15s/step - loss: 0.6209 - accuracy: 0.6278 - val_loss: 0.5777 - val_accuracy: 0.7614
# Epoch 2/30
# 150/150 [==============================] - 2329s 16s/step - loss: 0.4066 - accuracy: 0.8031 - val_loss: 1.2903 - val_accuracy: 0.2394
# Epoch 3/30
# 150/150 [==============================] - 2367s 16s/step - loss: 0.2308 - accuracy: 0.9188 - val_loss: 5.0062 - val_accuracy: 0.2431
# Epoch 4/30
# 121/150 [=======================>......] - ETA: 6:21 - loss: 0.1797 - accuracy: 0.9283

# %% [markdown]
# ### Evaluation:

# %%
model5.evaluate(train_aug)
# Out:
# 78/78 [==============================] - 146s 2s/step - loss: 0.0452 - accuracy: 0.9860
# [0.04519461840391159, 0.9859688878059387]

# %%
model5.evaluate(val_aug)
# Out:
# 20/20 [==============================] - 33s 2s/step - loss: 0.3066 - accuracy: 0.9121
# [0.3065687119960785, 0.9121212363243103]

# %% [markdown]
# #### Plotting Accuracy vs. Loss:

# %%
model_performance(hist)

# %% [markdown]
# This model is able to achieve a validation accuracy level of **91.2%** which is rather decent over 30 epochs. This is our best model yet and so I will save it:

# %%
#Saving the model
model4.save('model4.h5')

# %% [markdown]
# # Conclusion
# This project has shown how to benign and malignant diagnosis' from a set of skin lesion images and although it's far from perfect and could be improved, it is amazing to see the success of deep learning being used in real world problems.
#
# # Recommended Next Steps
# Re-run the models on the full dataset. I've originally done so, however give that the size of the file is so huge (4.18gb, over 25gb with augmentation), I was only able to run one model every few days (each model produced similar results as the ones aboe) and my kernel kept crashing, ultimately leaving me to keep restarting. However, now that I've completed this notebook I am able to simple update the dataset and rerun!
#
# Re-run some of the models with a greater number of epochs (such as 100 or more on the ones with 30) if necessary to determine if there is convergence. I've attempted this, however my system couldn't handle it.
#
# Fine tune and test other parameters to reduce overfitting as well as build a model with FN/FP/TN/TP metrics to get a more accurate look when the classes are imbalanced. (18)
#
# With this project as a base, our work can be built upon to detect more complex problems, such as determining the types of cancers, skin diseases related to Agent Orange and more.
#
# Output the model to a user friendly application, preferably a web app.

# %% [markdown]
# # References:

# %% [markdown]
# (1) https://docs.hashicorp.com/sentinel/imports/decimal
#
# (2) https://www.geeksforgeeks.org/convert-bgr-and-rgb-with-python-opencv/
#
# (3) https://datascience.stackexchange.com/questions/41921/sparse-categorical-crossentropy-vs-categorical-crossentropy-keras-accuracy
#
# (4) https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
#
# (5) https://pythonguides.com/python-print-2-decimal-places/#:~:text=Python%20print%202%20decimal%20places%20In%20Python%2C%20to,will%20print%20the%20float%20with%202%20decimal%20places.
#
# **EfficientNetB0:**
#
# https://keras.io/api/applications/efficientnet/
#
# https://paperswithcode.com/method/efficientnet
#
#
# (6) https://developers.google.com/machine-learning/crash-course/regularization-for-simplicity/l2-regularization
#
# (7) Thank you @python_wizard, @py_lenn, and @synthphreak from reddit for guiding me with this piece of code!
#
# (8) https://keras.io/api/callbacks/
#
# (9) https://keras.io/api/callbacks/reduce_lr_on_plateau/
#
# (10) https://keras.io/api/callbacks/model_checkpoint/
#
# (11) https://keras.io/api/callbacks/early_stopping
#
# (12) https://stackoverflow.com/questions/61362426/why-is-my-val-accuracy-stagnant-at-0-0000e00-while-my-val-loss-is-increasing-fr
#
# (13) https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a
#
# (14) https://stats.stackexchange.com/questions/260505/should-i-use-a-categorical-cross-entropy-or-binary-cross-entropy-loss-for-binary#:~:text=Binary%20cross-entropy%20is%20for%20multi-label%20classifications%2C%20whereas%20categorical,Thanks%20for%20contributing%20an%20answer%20to%20Cross%20Validated%21
#
# (15) https://keras.io/api/layers/convolution_layers/separable_convolution2d/
#
# (15A) https://towardsdatascience.com/a-basic-introduction-to-separable-convolutions-b99ec3102728
#
# **ResNet50:**
#
# (16) https://iq.opengenus.org/resnet50-architecture/
#
# (17) https://medium.com/@venkinarayanan/tutorial-image-classifier-using-resnet50-deep-learning-model-python-flask-in-azure-4c2b129af6d2
#
# (18) https://keras.io/examples/structured_data/imbalanced_classification/
#
# **VGG16:**
#
# (19) https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c
