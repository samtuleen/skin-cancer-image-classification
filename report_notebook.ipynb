# %% [markdown]
# ![R.png](attachment:R.png)

# %% [markdown]
# # Skin Lesion Classification: Cancer or Not?
# **By: Sameeha Ramadhan**

# %% [markdown]
# # Introduction:

# %% [markdown]
# The goal of this project is to build a tool to correctly identify if whether or not a skin lesion is cancerous. The model will take in a picture of said lesion and calculate the probability that said lesion is benign (non-cancerous) or malignant (cancer).

# %% [markdown]
# ## Business Problem:

# %% [markdown]
# The use of such an algorithm would assist doctors and medical professionals in decreasing the time it takes to review and diagnose a patient as well as benefitting the patient by knowing sooner than later if cancer is present so that treatment could begin promptly. In addition, if a person is in doubt about a particular mole but hesitant to visit the doctor, this tool could give peace of mind (by diagnosing as benign) or encourage an appointment (should it output malignant).

# %% [markdown]
# # Import:

# %% [markdown]
# The following packages run the models:

# %%
import os
import pandas as pd
import numpy as np
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
color = sns.color_palette("flare", as_cmap=True)

from keras.preprocessing import image
from keras.models import Model, Sequential
from keras import layers
from keras.utils.np_utils import to_categorical
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation, MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf

#!pip install efficientnet <---installed

import efficientnet.keras as efn
from keras.applications.resnet50 import ResNet50
from keras import regularizers 
from keras.regularizers import l2

import keras
import keras.backend
from IPython.display import display

import cv2


from skimage.io import imread
from skimage.transform import resize
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

np.random.seed(20)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# I'll begin by first accessing the main directory and listing its contents:

# %%
main_dir = 'C:\\Users\\15164\\Desktop\\skin\\'
data_directory = os.listdir('C:\\Users\\15164\\Desktop\\skin\\')
print(data_directory)
# Out:
# ['train', 'val']

# %% [markdown]
# Next, I'll print the contents of each sub directory and the number of files each folder contains.
#
# **Note: this notebook was run on a sample of the original dataset, which contains over 28,000 images. I've previously ran my models over the entire dataset, however my kernel kept crashing after days of running models and I had to keep restarting. I am currently running a separate notebook in batches and will update when completed.**

# %%
for _set in ['train', 'val']:
    x_benign = len(os.listdir(main_dir + _set + '\\benign'))
    x_malignant = len(os.listdir(main_dir + _set + '\\malignant'))
    print('Set: {}, Benign Images: {}, Malignant Images: {}, Total: {}'.format(_set, x_benign,
                                                                                x_malignant, (x_benign + x_malignant)))
# Out:
# Set: train, Benign Images: 15530, Malignant Images: 9063, Total: 24593
# Set: val, Benign Images: 3883, Malignant Images: 2266, Total: 6149

# %% [markdown]
# A simple plot to confirm the images have successfully loaded, and then I will check the balance of the data:

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train', 'val']):
    set_path = main_dir+_set
    ax[i].imshow(plt.imread(set_path+'\\benign\\'+os.listdir(set_path+'\\benign\\')[1]), cmap='gist_gray')
    ax[i].set_title('Set: {}, Diagnosis: Benign'.format(_set))
    ax[i+2].imshow(plt.imread(set_path+'\\malignant\\'+os.listdir(set_path+'\\malignant\\')[1]), cmap='gist_gray')
    ax[i+2].set_title('Set: {}, Diagnosis: Malignant'.format(_set))

# %% [markdown]
# ## Checking Data Balance:

# %%
train_dir = os.path.join(main_dir, "train\\")
test_dir = os.path.join(main_dir, "val\\")

# %% [markdown]
# I'll create dataframes to plot the data and check its distribution:

# %%
#Train data:
train_df = []

benign_set = os.path.join(train_dir,'benign')
malignant_set = os.path.join(train_dir,'malignant')

#Image list:

benign_images = glob(benign_set+"/*.jpg") + glob(benign_set+"/*.jpeg") + glob(benign_set+"/*.png")
malignant_images = glob(malignant_set + "/*.jpg") + glob(malignant_set + "/*.jpeg") + glob(malignant_set + "/*.png")

#Benign scans are labeled 0:
for img in benign_images:
    train_df.append((img, 0))

#Malignant are labeled 1:
for img in malignant_images:
    train_df.append((img, 1))

#Creating a dataframe:
train_df = pd.DataFrame(train_df, columns=['Image', 'Diagnosis'], index=None)

# %%
#Test data:
test_df = []

benign_set = os.path.join(test_dir,'benign')
malignant_set = os.path.join(test_dir,'malignant')

#Image list:
benign_images = glob(benign_set+"/*.jpg") + glob(benign_set+"/*.jpeg") + glob(benign_set+"/*.png")
malignant_images = glob(malignant_set + "/*.jpg") + glob(malignant_set + "/*.jpeg") + glob(malignant_set + "/*.png")

#Benign scans are labeled 0:
for img in benign_images:
    test_df.append((img, 0))

#Malignant are labeled 1:
for img in malignant_images:
    test_df.append((img, 1))

#Create the dataframe:
test_df = pd.DataFrame(test_df, columns=['Image', 'Diagnosis'], index=None)

# %% [markdown]
# ## Plotting Binary Data:

# %%
def balance_check(data):
#'data': the dfs we've created
    image_count = data['Diagnosis'].value_counts()
    print('Counts:')
    print(image_count)
    
    plt.figure(figsize=(11,7))
    sns.barplot(x= image_count.index, y= image_count.values)
    plt.title('Plot of Diagnosis Balancing', fontsize= 14)
    plt.xlabel('Diagnosis', fontsize= 11)
    plt.ylabel('Image Count', fontsize= 11)
    plt.xticks(range(len(image_count.index)), ['Benign(0)', 'Malignant(1)'])
    plt.show()

# %%
balance_check(train_df)
# Out:
# Counts:
# 0    15530
# 1     9063
# Name: Diagnosis, dtype: int64

# %%
balance_check(test_df)
# Out:
# Counts:
# 0    3883
# 1    2266
# Name: Diagnosis, dtype: int64

# %% [markdown]
# ### Model Visualization Function:

# %% [markdown]
# Now I'll define a function that plots the accuracy and loss results of my CNN models for easy interpretation:

# %%
def model_performance(history):
    
    history_dict = history.history
    train_loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']#<--'val' here is for validation, and will be from the 'test' dataset
    train_accuracy = history_dict['accuracy']
    val_accuracy = history_dict['val_accuracy']

    fig, axis = plt.subplots(ncols=1, nrows=2, figsize=(8,8))
    
    #Plotting loss results:    
    epochs = range(1, len(val_loss_values) + 1) #epoch: the number of times the model will be fit on the training set.
    plot1 = sns.lineplot(ax=axis[0], x=epochs, y=train_loss_values, label='Train Loss')
    plot1 = sns.lineplot(ax=axis[0], x=epochs, y=val_loss_values, label='Val Loss')
    plot1.set(xlabel='Epochs', ylabel='Loss')
    plot1.axes.set_title('Model Loss', fontsize=18)
    plot1.grid(b=True, which='major', axis='y') #To show the grid lines or not
    
    plot2 = sns.lineplot(ax=axis[1], x=epochs, y=train_accuracy, label='Train Accuracy')
    plot2 = sns.lineplot(ax=axis[1], x=epochs, y=val_accuracy, label='Val Accuracy')
    plot2.set(xlabel='Epochs', ylabel='Accuracy')
    plot2.axes.set_title('Model Accuracy', fontsize=20)
    plot2.grid(b=True, which='major', axis='y')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 5 Block CNN Models: VGG16 Architecture

# %% [markdown]
# ## Image Augmentation:

# %%
def data_processing(img_dims, batch_size):
    train_data_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True)
    test_data_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, vertical_flip=True) #scaling the images 
    #to the same range [0,1]
    
    # This is fed to the network in the specified batch sizes and image dimensions
    train_generator = train_data_gen.flow_from_directory(
    directory=train_dir, 
    target_size=(img_dims, img_dims),  #Each image will be resized to this size
    batch_size=batch_size, #number of observations that are inputted into the model at one time
    class_mode='binary', 
    shuffle=True)

    test_generator = test_data_gen.flow_from_directory(
    directory=test_dir, 
    target_size=(img_dims, img_dims), 
    batch_size=batch_size, 
    class_mode='binary', 
    shuffle=False)
    
    # In order to plot the Confusion Matrix, I will be making predictions off of the test set in one batch size
    test_data = []
    test_labels = []

    for cond in ['/benign/', '/malignant/']:
        for img in (os.listdir(main_dir + 'val' + cond)):
            img = plt.imread(main_dir+'val'+cond+img)
            img = cv2.resize(img, (img_dims, img_dims))
            img = np.dstack([img, img, img])
            img = img.astype('float32') / 255
            if cond=='/benign/':
                label = 0
            elif cond=='/malignant/':
                label = 1
            test_data.append(img)
            test_labels.append(label)
        
    test_data = np.array(test_data)
    test_labels = np.array(test_labels)
    
    return train_generator, test_generator, test_data, test_labels

# %%
#Values for later use:
img_dims = 224
epochs = 30
batch_size = 20
train_generator, test_generator, test_data, test_labels = data_processing(img_dims, batch_size)
# Out:
# Found 24593 images belonging to 2 classes.
# Found 6149 images belonging to 2 classes.

# %% [markdown]
# ## Model 1:

# %% [markdown]
# Defining the model architecture and compiling (19):

# %%
inputs = Input(shape=(img_dims, img_dims, 3))

#1st Convolution
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#2nd Convolution
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model) #(15)
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#3rd Convolution
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#4th Convolution
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.2)(model)

#5th Convolution
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.2)(model)

# Fully Connected layer
model = Flatten()(model)
model = Dense(units=512, activation='relu')(model)
model = Dropout(rate=0.6)(model)
model = Dense(units=128, activation='relu')(model)
model = Dropout(rate=0.4)(model)
model = Dense(units=64, activation='relu')(model)
model = Dropout(rate=0.2)(model)

# Output layer
output = Dense(units=1, activation='sigmoid')(model) #<--Converting a real value into a interpretable probability

# Creating model and compiling
model = Model(inputs=inputs, outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(filepath='best_weights.hdf5', save_best_only=True, save_weights_only=True)
#hdf5 (Hierarchical Data Format) is to store the weights of the best performing epoch
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=2, mode='max') #<--Reduce learning rate 
#when the metric has stopped improving.
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=1, mode='min')

# %% [markdown]
# Fitting (training) the model:

# %%
hist = model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, 
           epochs=epochs, validation_data=test_generator, shuffle=True,
           validation_steps=test_generator.samples // batch_size, callbacks=[checkpoint, lr_reduce])
# Out:
# Epoch 1/30
# 1229/1229 [==============================] - 1675s 1s/step - loss: 0.4219 - accuracy: 0.8145 - val_loss: 0.5372 - val_accuracy: 0.7150
# Epoch 2/30
# 1229/1229 [==============================] - 1619s 1s/step - loss: 0.3039 - accuracy: 0.8848 - val_loss: 0.4099 - val_accuracy: 0.8321
# Epoch 3/30
# 1229/1229 [==============================] - 1606s 1s/step - loss: 0.2729 - accuracy: 0.9004 - val_loss: 1.1779 - val_accuracy: 0.4695
# Epoch 4/30
# 1229/1229 [==============================] - 1611s 1s/step - loss: 0.2568 - accuracy: 0.9040 - val_loss: 0.4615 - val_accuracy: 0.8254
# Epoch 5/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9119
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1229/1229 [==============================] - 1604s 1s/step - loss: 0.2409 - accuracy: 0.9119 - val_loss: 0.4720 - val_accuracy: 0.7888
# Epoch 6/30
# 1229/1229 [==============================] - 1608s 1s/step - loss: 0.2076 - accuracy: 0.9200 - val_loss: 0.2021 - val_accuracy: 0.9213
# Epoch 7/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9229
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1229/1229 [==============================] - 1602s 1s/step - loss: 0.1974 - accuracy: 0.9229 - val_loss: 0.2030 - val_accuracy: 0.9112
# Epoch 8/30
# 1229/1229 [==============================] - 1608s 1s/step - loss: 0.1878 - accuracy: 0.9265 - val_loss: 0.1875 - val_accuracy: 0.9254
# Epoch 9/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9282
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1229/1229 [==============================] - 1600s 1s/step - loss: 0.1827 - accuracy: 0.9282 - val_loss: 0.1702 - val_accuracy: 0.9308
# Epoch 10/30
# 1229/1229 [==============================] - 1604s 1s/step - loss: 0.1802 - accuracy: 0.9289 - val_loss: 0.1772 - val_accuracy: 0.9277
# Epoch 11/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9295
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1229/1229 [==============================] - 1603s 1s/step - loss: 0.1778 - accuracy: 0.9295 - val_loss: 0.1693 - val_accuracy: 0.9319
# Epoch 12/30
# 1229/1229 [==============================] - 1604s 1s/step - loss: 0.1750 - accuracy: 0.9295 - val_loss: 0.1691 - val_accuracy: 0.9301
# Epoch 13/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9305
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 1229/1229 [==============================] - 1605s 1s/step - loss: 0.1739 - accuracy: 0.9305 - val_loss: 0.1673 - val_accuracy: 0.9306
# Epoch 14/30
# 1229/1229 [==============================] - 1604s 1s/step - loss: 0.1737 - accuracy: 0.9300 - val_loss: 0.1682 - val_accuracy: 0.9306
# Epoch 15/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9308
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 1229/1229 [==============================] - 1606s 1s/step - loss: 0.1756 - accuracy: 0.9308 - val_loss: 0.1704 - val_accuracy: 0.9283
# Epoch 16/30
# 1229/1229 [==============================] - 1607s 1s/step - loss: 0.1759 - accuracy: 0.9300 - val_loss: 0.1714 - val_accuracy: 0.9280
# Epoch 17/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9293
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 1229/1229 [==============================] - 1607s 1s/step - loss: 0.1778 - accuracy: 0.9293 - val_loss: 0.1703 - val_accuracy: 0.9301
# Epoch 18/30
# 1229/1229 [==============================] - 1607s 1s/step - loss: 0.1766 - accuracy: 0.9303 - val_loss: 0.1697 - val_accuracy: 0.9288
# Epoch 19/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9298
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 1229/1229 [==============================] - 1608s 1s/step - loss: 0.1757 - accuracy: 0.9298 - val_loss: 0.1699 - val_accuracy: 0.9292
# Epoch 20/30
# 1229/1229 [==============================] - 1604s 1s/step - loss: 0.1758 - accuracy: 0.9291 - val_loss: 0.1689 - val_accuracy: 0.9309
# Epoch 21/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9309
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 1229/1229 [==============================] - 1605s 1s/step - loss: 0.1747 - accuracy: 0.9309 - val_loss: 0.1663 - val_accuracy: 0.9319
# Epoch 22/30
# 1229/1229 [==============================] - 1618s 1s/step - loss: 0.1766 - accuracy: 0.9296 - val_loss: 0.1684 - val_accuracy: 0.9305
# Epoch 23/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9302
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# 1229/1229 [==============================] - 1614s 1s/step - loss: 0.1745 - accuracy: 0.9302 - val_loss: 0.1702 - val_accuracy: 0.9296
# Epoch 24/30
# 1229/1229 [==============================] - 1607s 1s/step - loss: 0.1738 - accuracy: 0.9311 - val_loss: 0.1711 - val_accuracy: 0.9300
# Epoch 25/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9302
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# 1229/1229 [==============================] - 1620s 1s/step - loss: 0.1746 - accuracy: 0.9302 - val_loss: 0.1670 - val_accuracy: 0.9303
# Epoch 26/30
# 1229/1229 [==============================] - 1613s 1s/step - loss: 0.1739 - accuracy: 0.9307 - val_loss: 0.1726 - val_accuracy: 0.9300
# Epoch 27/30
# 1229/1229 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9305
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# 1229/1229 [==============================] - 1634s 1s/step - loss: 0.1747 - accuracy: 0.9305 - val_loss: 0.1722 - val_accuracy: 0.9300
# Epoch 28/30
#  719/1229 [================>.............] - ETA: 10:09 - loss: 0.1741 - accuracy: 0.9307

# %% [markdown]
# Checking the perfomance:

# %%
model_performance(hist)

# %% [markdown]
# Now I'll calculate the confusion matrix:

# %%
preds = model.predict(test_generator)

accur = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()
#tp = true positive tn = true negative fp = false positive fn = false negative


print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(accur))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train Accuracy: {}'.format(np.round((hist.history["accuracy"][-1])*100, 2)))
# Out:
# CONFUSION MATRIX ------------------
# [[298  62]
#  [ 30 270]]
#
# TEST METRICS ----------------------
# Accuracy: 86.06060606060606%
# Precision: 81.32530120481928%
# Recall: 90.0%
# F1-score: 85.44303797468355
#
# TRAIN METRIC ----------------------
# Train Accuracy: 83.94

# %% [markdown]
# And finally visualize the matrix:

# %%
cm = pd.DataFrame(cm, index = ['Actual Benign', 'Actual Malignant'], columns = ['Predicted Benign', 'Predicted Malignant'])
plt.figure(figsize = (8,7))
labels = ['Benign', 'Malignant']
sns.heatmap(cm, cmap= "Blues", linecolor = 'black' , linewidth = 1, annot = True, fmt='')
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.show()

# %% [markdown]
# As shown in our matrix, our model produced semi-decent results with an 86% accuracy score. This means that out of 270 patients, 30 of them may be misdiagnosed as healthy when in fact they have a cancerous lesion. These numbers mean that 1 out of 9 will potentially not receive the care they need due to a wrong diagnosis, and while the numbers aren't too bad, when it comes to the health of a person these numbers are not ideal. And so, I will continue with a new model:

# %% [markdown]
# ## Model 2:

# %%
inputs = Input(shape=(img_dims, img_dims, 3))

#1st Convolution
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
model = Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#2nd Convolution
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model) #(15)
model = SeparableConv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(x)
model = MaxPool2D(pool_size=(2, 2))(x)

#3rd Convolution
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)

#4th Convolution
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.3)(model)#<--Updated dropout rate

#5th Convolution
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = SeparableConv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same')(model)
model = BatchNormalization()(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Dropout(rate=0.3)(model)

# Fully Connected layer
model = Flatten()(x)
model = Dense(units=512, activation='relu')(model)
model = Dropout(rate=0.6)(model) #<--Updated dropout rate
model = Dense(units=128, activation='relu')(model)
model = Dropout(rate=0.4)(model) #<--Updated dropout rate
model = Dense(units=64, activation='relu')(model)
model = Dropout(rate=0.2)(model)#<--Updated dropout rate

# Output layer
output = Dense(units=1, activation='sigmoid')(model) #<--Converting a real value into a interpretable probability

# Creating model and compiling
model2 = Model(inputs=inputs, outputs=output)
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(filepath='best_weights2.hdf5', save_best_only=True, save_weights_only=True)
#hdf5 (Hierarchical Data Format) is to store the weights of the best performing epoch
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5, verbose=2, mode='max') #<--Reduce learning rate 
#when the metric has stopped improving.
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=20, mode='min')

# %% [markdown]
# I'll fit the model with 30 epochs and a larger batch size:

# %%
hist = model2.fit(train_generator, epochs=30, validation_data=test_generator,
                  shuffle=True, batch_size = 128, callbacks=[checkpoint, lr_reduce, early_stop])
# Out:
# Epoch 1/30
# 264/264 [==============================] - 279s 1s/step - loss: 0.6010 - accuracy: 0.6811 - val_loss: 0.6934 - val_accuracy: 0.4545
# Epoch 2/30
# 264/264 [==============================] - 278s 1s/step - loss: 0.4926 - accuracy: 0.7672 - val_loss: 1.3153 - val_accuracy: 0.5455
# Epoch 3/30
# 264/264 [==============================] - 277s 1s/step - loss: 0.4659 - accuracy: 0.7903 - val_loss: 0.5496 - val_accuracy: 0.7333
# Epoch 4/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.4507 - accuracy: 0.7941 - val_loss: 0.4978 - val_accuracy: 0.7848
# Epoch 5/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.4526 - accuracy: 0.8111 - val_loss: 0.4604 - val_accuracy: 0.7803
# Epoch 6/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.4326 - accuracy: 0.8111 - val_loss: 0.3834 - val_accuracy: 0.8136
# Epoch 7/30
# 264/264 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.8157
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 264/264 [==============================] - 274s 1s/step - loss: 0.4149 - accuracy: 0.8157 - val_loss: 0.6623 - val_accuracy: 0.4727
# Epoch 8/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3885 - accuracy: 0.8191 - val_loss: 0.4510 - val_accuracy: 0.7545
# Epoch 9/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3924 - accuracy: 0.8229 - val_loss: 0.4291 - val_accuracy: 0.7864
# Epoch 10/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3575 - accuracy: 0.8362 - val_loss: 0.3511 - val_accuracy: 0.8197
# Epoch 11/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3795 - accuracy: 0.8256 - val_loss: 0.3394 - val_accuracy: 0.8394
# Epoch 12/30
# 264/264 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8472
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 264/264 [==============================] - 273s 1s/step - loss: 0.3547 - accuracy: 0.8472 - val_loss: 0.5629 - val_accuracy: 0.8045
# Epoch 13/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3438 - accuracy: 0.8445 - val_loss: 0.3389 - val_accuracy: 0.8258
# Epoch 14/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3464 - accuracy: 0.8498 - val_loss: 0.4070 - val_accuracy: 0.7803
# Epoch 15/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3423 - accuracy: 0.8468 - val_loss: 0.3974 - val_accuracy: 0.7848
# Epoch 16/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3384 - accuracy: 0.8441 - val_loss: 0.3337 - val_accuracy: 0.8394
# Epoch 17/30
# 264/264 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.8491
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 264/264 [==============================] - 274s 1s/step - loss: 0.3353 - accuracy: 0.8491 - val_loss: 0.3500 - val_accuracy: 0.8439
# Epoch 18/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3152 - accuracy: 0.8586 - val_loss: 0.3299 - val_accuracy: 0.8439
# Epoch 19/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3209 - accuracy: 0.8593 - val_loss: 0.3320 - val_accuracy: 0.8439
# Epoch 20/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3293 - accuracy: 0.8601 - val_loss: 0.3430 - val_accuracy: 0.8500
# Epoch 21/30
# 264/264 [==============================] - 277s 1s/step - loss: 0.3125 - accuracy: 0.8642 - val_loss: 0.3321 - val_accuracy: 0.8439
# Epoch 22/30
# 264/264 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8586
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 264/264 [==============================] - 273s 1s/step - loss: 0.3175 - accuracy: 0.8586 - val_loss: 0.3366 - val_accuracy: 0.8394
# Epoch 23/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3143 - accuracy: 0.8608 - val_loss: 0.3295 - val_accuracy: 0.8500
# Epoch 24/30
# 264/264 [==============================] - 275s 1s/step - loss: 0.3222 - accuracy: 0.8529 - val_loss: 0.3300 - val_accuracy: 0.8500
# Epoch 25/30
# 264/264 [==============================] - 273s 1s/step - loss: 0.3129 - accuracy: 0.8582 - val_loss: 0.3389 - val_accuracy: 0.8439
# Epoch 26/30
# 264/264 [==============================] - 274s 1s/step - loss: 0.3113 - accuracy: 0.8661 - val_loss: 0.3329 - val_accuracy: 0.8424

# %% [markdown]
# I'll plot the performance:

# %%
model_performance(hist)

# %%
preds = model3.predict(test_generator)

accur = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()
#tp = true positive tn = true negative fp = false positive fn = false negative


print('CONFUSION MATRIX ------------------')
print(cm)

print('\nTEST METRICS ----------------------')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(accur))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train Accuracy: {}'.format(np.round((hist.history["accuracy"][-1])*100, 2)))
# Out:
# CONFUSION MATRIX ------------------
# [[302  58]
#  [ 38 262]]
#
# TEST METRICS ----------------------
# Accuracy: 85.45454545454545%
# Precision: 81.875%
# Recall: 87.33333333333333%
# F1-score: 84.51612903225806
#
# TRAIN METRIC ----------------------
# Train Accuracy: 86.2

# %%
cm = pd.DataFrame(cm, index = ['Actual Benign', 'Actual Malignant'], columns = ['Predicted Benign', 'Predicted Malignant'])
plt.figure(figsize = (8,7))
labels = ['Benign', 'Malignant']
sns.heatmap(cm, cmap= "Blues", linecolor = 'black' , linewidth = 1, annot = True, fmt='')
plt.xlabel('Predicted', fontsize=14)
plt.ylabel('True', fontsize=14)
plt.show()

# %% [markdown]
# So, our accuracy increased a bit from our last model (86% train and 85% test) however according to our confusion matrix, 1 out of 6 will be misdiagnosed as healthy while having cancer. This model has produced less favorable results than our previous one.

# %% [markdown]
# # Model 3: CNN w/No Augmentation:

# %%
from decimal import * #<--The decimal import provides functions for operating on numbers represented as decimals. (1)
from keras.preprocessing.image import  load_img
from keras.models import load_model 
import glob as glob

# %%
#Input values:
img_width=224
img_height=224
batch_size=64
input_shape=(img_width,img_width,3)

# %% [markdown]
# Next I'll define my classes and resize the images:

# %%
label = ['benign','malignant']

path = {}
x_train=[]
y_train=[]
classs=0
for img in label:
    path[img] = glob.glob(os.path.join(r'C:\\Users\\15164\\Desktop\\skin\\train\\', img, '*'))
    for image in path[img]:
        x_train.append(cv2.resize(cv2.imread(image),(img_width,img_width)))
        y_train.append(classs)
    classs=classs+1
    print(len(path[img]))
# Out:
# 1440
# 1197

# %%
path = {}
x_test=[]
y_test=[]
classs=0
for img in label:
    path[img] = glob.glob(os.path.join(r'C:\\Users\\15164\\Desktop\\skin\\val\\', img, '*'))
    for image in path[img]:
        x_test.append(cv2.resize(cv2.imread(image),(img_width,img_width)))
        y_test.append(classs)
    classs=classs+1
    print(len(path[img]))
# Out:
# 360
# 300

# %% [markdown]
# A quick check that images can be loaded:

# %%
plt.imshow(cv2.cvtColor(x_train[-1], cv2.COLOR_BGR2RGB)) #<--Converting BGR image to RGB since image processing 
#libraries have different pixel orderings. (2)
plt.title(label[y_train[-1]])
plt.show()

# %%
#Normalization
x_train =  np.array(x_train[:])
x_train =  x_train / 255

# %% [markdown]
# Now on to defining my model's architecture:

# %%
model3 = Sequential()

model3.add(Conv2D(32, (3,3), input_shape = (input_shape), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))


model3.add(Conv2D(32, (3,3), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))

model3.add(Conv2D(64, (3,3), activation = 'relu'))
model3.add(MaxPooling2D(pool_size = (2, 2)))
model3.add(Dropout(0.2))

model3.add(Flatten())

model3.add(Dense(units = 4096, activation = 'relu'))
model3.add(Dense(units = 2048, activation = 'relu'))
model3.add(Dropout(0.2))

model3.add(Dense(units = len(label), activation = 'softmax'))


model3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_57 (Dense)             (None, 4096)              51384320
# _________________________________________________________________
# dense_58 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_59 (Dense)             (None, 2)                 4098
# =================================================================
# Total params: 59,807,714
# Trainable params: 59,807,714
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# I'll compile my model using sparse categorical crossentropy as my loss since my classes are mutually exclusive (meaning each sample belongs exactly to one class). (3) Also, due to the nature of my original dataset(very large and contains images that are very noisy with a lot of gradients) I'll optimize using 'Adam' because it is computationally efficient, has little memory requirements, the most suitable for problems that are large in terms of data and/or parameters, and is appropriate for problems with gradients. (4)

# %%
model3.compile(loss = 'sparse_categorical_crossentropy', optimizer ='adam', metrics = ['accuracy'])

# %% [markdown]
# And now, we train our model:

# %%
hist = model3.fit(x_train, np.array(y_train),epochs=100,batch_size=64)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 75s 2s/step - loss: 1.2936 - accuracy: 0.5745
# Epoch 2/100
# 42/42 [==============================] - 60s 1s/step - loss: 0.5352 - accuracy: 0.7383
# Epoch 3/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.4880 - accuracy: 0.7672
# Epoch 4/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.4376 - accuracy: 0.7838
# Epoch 5/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.4220 - accuracy: 0.7994
# Epoch 6/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.3949 - accuracy: 0.8051
# Epoch 7/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.3864 - accuracy: 0.8089
# Epoch 8/100
# 42/42 [==============================] - 59s 1s/step - loss: 0.3761 - accuracy: 0.8127
# Epoch 9/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.3555 - accuracy: 0.8290
# Epoch 10/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.3587 - accuracy: 0.8153
# Epoch 11/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.3600 - accuracy: 0.8331
# Epoch 12/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3490 - accuracy: 0.8294
# Epoch 13/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3662 - accuracy: 0.8203
# Epoch 14/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3521 - accuracy: 0.8256
# Epoch 15/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3282 - accuracy: 0.8434
# Epoch 16/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3300 - accuracy: 0.8373
# Epoch 17/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3291 - accuracy: 0.8400
# Epoch 18/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.3103 - accuracy: 0.8491
# Epoch 19/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2851 - accuracy: 0.8707
# Epoch 20/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2955 - accuracy: 0.8555
# Epoch 21/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2803 - accuracy: 0.8677
# Epoch 22/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2469 - accuracy: 0.8896
# Epoch 23/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.2591 - accuracy: 0.8813
# Epoch 24/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.2421 - accuracy: 0.8900
# Epoch 25/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2371 - accuracy: 0.8881
# Epoch 26/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.2493 - accuracy: 0.8862
# Epoch 27/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.2246 - accuracy: 0.8938
# Epoch 28/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.2100 - accuracy: 0.9071
# Epoch 29/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1773 - accuracy: 0.9226
# Epoch 30/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1648 - accuracy: 0.9261
# Epoch 31/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1921 - accuracy: 0.9139
# Epoch 32/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1550 - accuracy: 0.9363
# Epoch 33/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1561 - accuracy: 0.9333
# Epoch 34/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1383 - accuracy: 0.9439
# Epoch 35/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1510 - accuracy: 0.9329
# Epoch 36/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1230 - accuracy: 0.9496
# Epoch 37/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1116 - accuracy: 0.9503
# Epoch 38/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.1206 - accuracy: 0.9537
# Epoch 39/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1010 - accuracy: 0.9564
# Epoch 40/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0869 - accuracy: 0.9693
# Epoch 41/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1291 - accuracy: 0.9435
# Epoch 42/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0912 - accuracy: 0.9613
# Epoch 43/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0832 - accuracy: 0.9651
# Epoch 44/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0894 - accuracy: 0.9636
# Epoch 45/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0981 - accuracy: 0.9568
# Epoch 46/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0725 - accuracy: 0.9666
# Epoch 47/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0572 - accuracy: 0.9754
# Epoch 48/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.0596 - accuracy: 0.9757
# Epoch 49/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1022 - accuracy: 0.9579
# Epoch 50/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0622 - accuracy: 0.9746
# Epoch 51/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.1107 - accuracy: 0.9625
# Epoch 52/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0548 - accuracy: 0.9810
# Epoch 53/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0509 - accuracy: 0.9784
# Epoch 54/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0401 - accuracy: 0.9848
# Epoch 55/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0535 - accuracy: 0.9788
# Epoch 56/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0551 - accuracy: 0.9788
# Epoch 57/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0648 - accuracy: 0.9716
# Epoch 58/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0319 - accuracy: 0.9886
# Epoch 59/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0559 - accuracy: 0.9788
# Epoch 60/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.0350 - accuracy: 0.9879
# Epoch 61/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0622 - accuracy: 0.9810
# Epoch 62/100
# 42/42 [==============================] - 55s 1s/step - loss: 0.0297 - accuracy: 0.9882
# Epoch 63/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0406 - accuracy: 0.9875
# Epoch 64/100
# 42/42 [==============================] - 55s 1s/step - loss: 0.0547 - accuracy: 0.9833
# Epoch 65/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0808 - accuracy: 0.9700
# Epoch 66/100
# 42/42 [==============================] - 55s 1s/step - loss: 0.0467 - accuracy: 0.9826
# Epoch 67/100
# 42/42 [==============================] - 55s 1s/step - loss: 0.0207 - accuracy: 0.9928
# Epoch 68/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0123 - accuracy: 0.9951
# Epoch 69/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0254 - accuracy: 0.9898
# Epoch 70/100
# 42/42 [==============================] - 59s 1s/step - loss: 0.0591 - accuracy: 0.9814
# Epoch 71/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0326 - accuracy: 0.9875
# Epoch 72/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0451 - accuracy: 0.9845
# Epoch 73/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0366 - accuracy: 0.9860
# Epoch 74/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0305 - accuracy: 0.9901
# Epoch 75/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0144 - accuracy: 0.9954
# Epoch 76/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0107 - accuracy: 0.9966
# Epoch 77/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0162 - accuracy: 0.9951
# Epoch 78/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0239 - accuracy: 0.9917
# Epoch 79/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0149 - accuracy: 0.9932
# Epoch 80/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0191 - accuracy: 0.9928
# Epoch 81/100
# 42/42 [==============================] - 57s 1s/step - loss: 0.0245 - accuracy: 0.9932
# Epoch 82/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0405 - accuracy: 0.9863
# Epoch 83/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0171 - accuracy: 0.9932
# Epoch 84/100
# 42/42 [==============================] - 60s 1s/step - loss: 0.0245 - accuracy: 0.9932
# Epoch 85/100
# 42/42 [==============================] - 59s 1s/step - loss: 0.0095 - accuracy: 0.9973
# Epoch 86/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.0557 - accuracy: 0.9833
# Epoch 87/100
# 42/42 [==============================] - 58s 1s/step - loss: 0.0196 - accuracy: 0.9920
# Epoch 88/100
# 42/42 [==============================] - 59s 1s/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 89/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0114 - accuracy: 0.9962
# Epoch 90/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0095 - accuracy: 0.9973
# Epoch 91/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0032 - accuracy: 0.9985
# Epoch 92/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0065 - accuracy: 0.9985
# Epoch 93/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0152 - accuracy: 0.9947
# Epoch 94/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 95/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0020 - accuracy: 0.9992
# Epoch 96/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0079 - accuracy: 0.9981
# Epoch 97/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0111 - accuracy: 0.9954
# Epoch 98/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0277 - accuracy: 0.9928
# Epoch 99/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0140 - accuracy: 0.9954
# Epoch 100/100
# 42/42 [==============================] - 56s 1s/step - loss: 0.0197 - accuracy: 0.9932

# %% [markdown]
# ## Evaluate:

# %%
scores = model3.evaluate(x_test,np.array(y_test))
print("Accuracy = " + format(scores[1]*100, '.2f') + "%") #<-- "".2f" to print 2 decimal places as a string and float (5)
# Out:
# 21/21 [==============================] - 8s 379ms/step - loss: 0.9207 - accuracy: 0.8379
# Accuracy = 83.79%

# %%
fig, axis = plt.subplots(ncols=1, nrows=1, figsize=(10,5))
plot1= plt.plot(hist.history['accuracy'])
plot2=plt.plot(hist.history['loss'])
plot2=plt.title('Model Accuracy and Loss')
plot2=plt.ylabel('loss/accuracy')
plot2=plt.xlabel('epoch')
plot2=plt.legend(['accuracy', 'loss'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see from the accuracy score and the above accuracy/loss plot, our intial model performed well on our training set with a 99.3% accuracy and 0.019 loss. However, it's performed fairly decent on our test set, gaining an accuracy score of 83%.

# %% [markdown]
# # Model 4: EfficientNetB0

# %% [markdown]
# For my next model I've chosen to use EfficientNetB0, a pretrained image classification model that is optimized for state of the art accuracy while being smaller and faster. I've chosen this model because it comes from a family of models that have faster training speed and better parameter efficiency. [For more on EfficientNet models see references below]

# %%
#To free up memory space since our dataset is so large (the kernel kept crashing):
tf.keras.backend.clear_session()

# %%
s = 20
np.random.seed(s)
tf.random.set_seed(s)

# %%
#Resizing the images to a uniform size (a bit smaller than the usual 224 to save some memory space)
def resize_images(directory, resize):
    images = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for image_name in os.listdir(directory):
        PATH = os.path.join(directory, image_name)
        _, ftype = os.path.splitext(PATH)
        if ftype.endswith((".jpg", ".jpeg", ".png")):
            img = read(PATH)
            img = cv2.resize(img, (resize, resize))
            images.append(np.array(img)/255.) #<-- EfficientNet models require inputs to be float tensors of pixels
            #w/ values in the [0-255] range.
    return images

# %%
benign_train = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\train\\benign', 128))

# %%
malign_train = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\train\\malignant', 128))

# %%
benign_test = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\val\\benign', 128))

# %%
malign_test = np.array(resize_images('C:\\Users\\15164\\Desktop\\skin\\val\\malignant', 128))

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merging
x_train = np.concatenate((benign_train, malign_train), axis = 0)
y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
x_test = np.concatenate((benign_test, malign_test), axis = 0)
y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffling train data
sh = np.arange(x_train.shape[0])
np.random.shuffle(sh)
x_train = x_train[sh]
y_train = y_train[sh]

# Shuffling test data
sh = np.arange(x_test.shape[0])
np.random.shuffle(sh)
x_test = x_test[sh]
y_test = y_test[sh]

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=s)

# %%
x_test.shape, x_val.shape, x_train.shape #<---Checking the split's success:
# Out:
# ((1557, 224, 224, 3), (528, 224, 224, 3), (2109, 224, 224, 3))

# %%
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)
y_val = to_categorical(y_val, num_classes= 2)

# %%
# normalization 
x_train = x_train/255.
x_test = x_test/255.
x_val = x_val/255.

#Rechecking shape:
x_test.shape,  x_train.shape, x_val.shape,
# Out:
# ((1557, 128, 128, 3), (2637, 128, 128, 3), (528, 224, 224, 3))

# %%
datagen = ImageDataGenerator(rotation_range=45, zoom_range = 0.1, width_shift_range=0.2, height_shift_range=0.2, 
                             horizontal_flip=True, vertical_flip=True)

# %%
eff_net = efn.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
model3=Sequential()
model3.add(eff_net)
model3.add(layers.GlobalAveragePooling2D())
model3.add(Dense(128, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dense(2, activation='softmax'))

#Setting kernel regulizer: <--this is done to help lessen the chances of overfitting the model (6), (7)
alpha = 1e-3
for layer in model2.layers:
    if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.Dense):
        layer.add_loss(lambda: keras.regularizers.l2(alpha)(layer.kernel))
    if hasattr(layer, 'bias_regularizer') and layer.use_bias:
        layer.add_loss(lambda: keras.regularizers.l2(alpha)(layer.bias)) 


model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Functional) (None, 7, 7, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1280)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               163968
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 4,214,302
# Trainable params: 4,172,030
# Non-trainable params: 42,272
# _________________________________________________________________

# %% [markdown]
# Defining our callbacks (objects that perform actions at different times during training)(8)

# %%
#Slowing learning when the metric stops improving (9)
reduce_lr= ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=0, mode='max', min_delta=0.0001,
                             cooldown=0, min_lr=0) 

#Saving best weights (10)
checkpoint = ModelCheckpoint(filepath='best_weights2.hdf5', save_best_only=True, save_weights_only=True) 

#Stopping when the validation loss is increases too much (11)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=20, mode='min', verbose = 1)

optimizer= Adam(lr=0.0001)

# %%
# Shuffling train data again
sh = np.arange(x_train.shape[0])
np.random.shuffle(sh)
x_train = x_train[sh]
y_train = y_train[sh]

# Shuffling test data
#sh = np.arange(x_test.shape[0])
#np.random.shuffle(sh)
#x_test = x_test[sh]
#y_test = y_test[sh]

# Shuffling validation data to avoid overfitting the model: (12)
sh = np.arange(x_val.shape[0])
np.random.shuffle(sh)
x_val = x_val[sh]
y_val = y_val[sh]

# %%
# Using binary_crossentropy since this is a binary problem (13), (14)
model3.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])
hist = model3.fit(datagen.flow(x_train, y_train, batch_size=10), epochs=20, steps_per_epoch= 200,
                  validation_data=(x_val, y_val),callbacks=[reduce_lr, checkpoint, early_stop])
# Out:
# Epoch 1/20
# 200/200 [==============================] - 392s 2s/step - loss: 0.6176 - accuracy: 0.7409 - val_loss: 1.1045 - val_accuracy: 0.5265
# Epoch 2/20
# 200/200 [==============================] - 379s 2s/step - loss: 0.4451 - accuracy: 0.8079 - val_loss: 5.8396 - val_accuracy: 0.5398
# Epoch 3/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.4153 - accuracy: 0.8209 - val_loss: 1.3205 - val_accuracy: 0.5114
# Epoch 4/20
# 200/200 [==============================] - 378s 2s/step - loss: 0.4110 - accuracy: 0.8204 - val_loss: 0.5910 - val_accuracy: 0.7576
# Epoch 5/20
# 200/200 [==============================] - 378s 2s/step - loss: 0.3425 - accuracy: 0.8509 - val_loss: 0.4448 - val_accuracy: 0.7955
# Epoch 6/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.3077 - accuracy: 0.8699 - val_loss: 0.3140 - val_accuracy: 0.8655
# Epoch 7/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.3133 - accuracy: 0.8674 - val_loss: 0.3574 - val_accuracy: 0.8504
# Epoch 8/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.2879 - accuracy: 0.8894 - val_loss: 0.3196 - val_accuracy: 0.8693
# Epoch 9/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.2702 - accuracy: 0.8844 - val_loss: 0.3066 - val_accuracy: 0.8845
# Epoch 10/20
# 200/200 [==============================] - 378s 2s/step - loss: 0.2830 - accuracy: 0.8809 - val_loss: 0.3154 - val_accuracy: 0.8636
# Epoch 11/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.2547 - accuracy: 0.9010 - val_loss: 0.3556 - val_accuracy: 0.8466
# Epoch 12/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.2452 - accuracy: 0.8974 - val_loss: 0.2837 - val_accuracy: 0.8958
# Epoch 13/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.2397 - accuracy: 0.9040 - val_loss: 0.3185 - val_accuracy: 0.8693
# Epoch 14/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.2338 - accuracy: 0.9070 - val_loss: 0.3004 - val_accuracy: 0.8883
# Epoch 15/20
# 200/200 [==============================] - 375s 2s/step - loss: 0.2250 - accuracy: 0.9070 - val_loss: 0.3127 - val_accuracy: 0.8750
# Epoch 16/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.2272 - accuracy: 0.9100 - val_loss: 0.3034 - val_accuracy: 0.8674
# Epoch 17/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.1983 - accuracy: 0.9210 - val_loss: 0.3294 - val_accuracy: 0.8598
# Epoch 18/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.1860 - accuracy: 0.9280 - val_loss: 0.3294 - val_accuracy: 0.8769
# Epoch 19/20
# 200/200 [==============================] - 376s 2s/step - loss: 0.1646 - accuracy: 0.9395 - val_loss: 0.3128 - val_accuracy: 0.8769
# Epoch 20/20
# 200/200 [==============================] - 377s 2s/step - loss: 0.1806 - accuracy: 0.9350 - val_loss: 0.3099 - val_accuracy: 0.8712

# %% [markdown]
# I'll use my previously defined function to plot the loss and accuracy for both the training and validation sets:

# %%
model_performance(hist)

# %% [markdown]
# And a quick evaluation of each set:

# %%
model3.evaluate(x_train, y_train)
# Out:
# 66/66 [==============================] - 64s 969ms/step - loss: 0.0911 - accuracy: 0.9649
# [0.09111281484365463, 0.9649122953414917]

# %%
model3.evaluate(x_val, y_val)
# Out:
# 17/17 [==============================] - 16s 953ms/step - loss: 0.3099 - accuracy: 0.8712
# [0.309896320104599, 0.8712121248245239]

# %%
model3.evaluate(x_test, y_test)
# Out:
# 49/49 [==============================] - 49s 991ms/step - loss: 0.2063 - accuracy: 0.9152
# [0.20628032088279724, 0.9152215719223022]

# %% [markdown]
# As we can see, our model is not overfit and it produced decent results as seen above: **96% accuracy on our training set, 87% for our validation, and 91% on our test set.**

# %% [markdown]
# # Model 5: ResNet50:

# %% [markdown]
# I will now build my final model using ResNet50 (16), a pretrained image classification model that consists of a 50 layer deep convolutional network. I've chosen this model because since my dataset is large and this particular model has been trained on thousands of images in very deep layers, I am hopeful this will achieve optimal accuracy results. (17)

# %% [markdown]
# First, I'll define my image size, the number of epochs, classes, batch size and my data augmentation.

# %%
height, width = (224, 224)
epochs = 30 
classes_name = ('benign','malignant')
batch_size = 34
imgdatagen = ImageDataGenerator(rescale = 1./255,
                                     rotation_range=45,  
                                     zoom_range = 0.2, 
                                     width_shift_range=0.2,  
                                     height_shift_range=0.2)

# %% [markdown]
# Now I'll augment:

# %%
train_aug = imgdatagen.flow_from_directory(train_dir, target_size = (height, width), 
                classes = classes_name,  batch_size = batch_size)

val_aug = imgdatagen.flow_from_directory(test_dir, target_size = (height, width), 
                classes = classes_name, batch_size = batch_size, shuffle=False)
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %% [markdown]
# Next I'll define my model's architecture by not including the top. This means I'll remove the last dense layers to allow the features of my model to be extracted. Then I will compile and finally, fit my model.

# %%
base_model= ResNet50(include_top=False, weights="imagenet", input_shape=(height, width,3))
model4= Sequential()
model4.add(base_model)
model4.add(Conv2D(64, (3, 3), activation = 'relu'))
model4.add(Dropout(0.2))
model4.add(Conv2D(64, (3, 3), activation = 'relu'))
model4.add(MaxPooling2D(pool_size = (2, 2)))
model4.add(Dropout(0.2))
model4.add(Flatten())
model4.add(Dense(512,activation='relu'))
model4.add(Dense(256,activation='relu'))
model4.add(Dropout(0.2))
model4.add(Dense(128,activation='relu'))
model4.add(Dense(64,activation='relu'))
model4.add(Dense(32,activation='relu'))
model4.add(Dense(16,activation='relu'))
model4.add(Dense(8,activation='relu'))
model4.add(Dense(2, activation='softmax'))
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 5, 5, 64)          1179712
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33280
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 25,012,874
# Trainable params: 24,959,754
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model4.compile(optimizer=Adam(lr=0.00001),loss="categorical_crossentropy",metrics=["accuracy"])

# %%
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=.5, min_lr=0.00001) 
hist = model4.fit(train_aug, steps_per_epoch=train_aug.samples//train_aug.batch_size,
                  validation_data=val_aug, verbose=1, validation_steps=val_aug.samples//val_aug.batch_size,
                  epochs=epochs, callbacks=[lr_reduce])
# Out:
# Epoch 1/30
# 77/77 [==============================] - 1112s 14s/step - loss: 0.6925 - accuracy: 0.5190 - val_loss: 0.6953 - val_accuracy: 0.4412
# Epoch 2/30
# 77/77 [==============================] - 1068s 14s/step - loss: 0.6558 - accuracy: 0.5939 - val_loss: 0.6983 - val_accuracy: 0.3560
# Epoch 3/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.5361 - accuracy: 0.7073 - val_loss: 0.7233 - val_accuracy: 0.4598
# Epoch 4/30
# 77/77 [==============================] - 948s 12s/step - loss: 0.4416 - accuracy: 0.8171 - val_loss: 0.8396 - val_accuracy: 0.4551
# Epoch 5/30
# 77/77 [==============================] - 947s 12s/step - loss: 0.3926 - accuracy: 0.8283 - val_loss: 0.9584 - val_accuracy: 0.4536
# Epoch 6/30
# 77/77 [==============================] - 959s 12s/step - loss: 0.3452 - accuracy: 0.8559 - val_loss: 0.9655 - val_accuracy: 0.4520
# Epoch 7/30
# 77/77 [==============================] - 959s 12s/step - loss: 0.3134 - accuracy: 0.8694 - val_loss: 0.9821 - val_accuracy: 0.4582
# Epoch 8/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.2833 - accuracy: 0.8801 - val_loss: 1.0539 - val_accuracy: 0.4427
# Epoch 9/30
# 77/77 [==============================] - 951s 12s/step - loss: 0.2625 - accuracy: 0.8840 - val_loss: 0.9802 - val_accuracy: 0.4195
# Epoch 10/30
# 77/77 [==============================] - 949s 12s/step - loss: 0.2322 - accuracy: 0.9043 - val_loss: 0.8544 - val_accuracy: 0.4814
# Epoch 11/30
# 77/77 [==============================] - 954s 12s/step - loss: 0.2306 - accuracy: 0.9001 - val_loss: 0.9376 - val_accuracy: 0.5944
# Epoch 12/30
# 77/77 [==============================] - 953s 12s/step - loss: 0.2082 - accuracy: 0.9139 - val_loss: 0.7998 - val_accuracy: 0.6981
# Epoch 13/30
# 77/77 [==============================] - 950s 12s/step - loss: 0.1971 - accuracy: 0.9139 - val_loss: 0.8026 - val_accuracy: 0.7307
# Epoch 14/30
# 77/77 [==============================] - 960s 12s/step - loss: 0.1799 - accuracy: 0.9262 - val_loss: 0.7598 - val_accuracy: 0.7353
# Epoch 15/30
# 77/77 [==============================] - 960s 12s/step - loss: 0.1701 - accuracy: 0.9324 - val_loss: 0.5149 - val_accuracy: 0.8220
# Epoch 16/30
# 77/77 [==============================] - 955s 12s/step - loss: 0.1603 - accuracy: 0.9358 - val_loss: 0.4028 - val_accuracy: 0.8437
# Epoch 17/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.1460 - accuracy: 0.9431 - val_loss: 0.4296 - val_accuracy: 0.8452
# Epoch 18/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.1452 - accuracy: 0.9439 - val_loss: 0.2590 - val_accuracy: 0.9056
# Epoch 19/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.1320 - accuracy: 0.9493 - val_loss: 0.2982 - val_accuracy: 0.8963
# Epoch 20/30
# 77/77 [==============================] - 962s 12s/step - loss: 0.1335 - accuracy: 0.9481 - val_loss: 0.3046 - val_accuracy: 0.8885
# Epoch 21/30
# 77/77 [==============================] - 952s 12s/step - loss: 0.1158 - accuracy: 0.9551 - val_loss: 0.2248 - val_accuracy: 0.9087
# Epoch 22/30
# 77/77 [==============================] - 954s 12s/step - loss: 0.1195 - accuracy: 0.9585 - val_loss: 0.2446 - val_accuracy: 0.9071
# Epoch 23/30
# 77/77 [==============================] - 957s 12s/step - loss: 0.1046 - accuracy: 0.9631 - val_loss: 0.3075 - val_accuracy: 0.8885
# Epoch 24/30
# 77/77 [==============================] - 956s 12s/step - loss: 0.0946 - accuracy: 0.9662 - val_loss: 0.2767 - val_accuracy: 0.8947
# Epoch 25/30
# 77/77 [==============================] - 954s 12s/step - loss: 0.0887 - accuracy: 0.9689 - val_loss: 0.2905 - val_accuracy: 0.8994
# Epoch 26/30
# 77/77 [==============================] - 953s 12s/step - loss: 0.0865 - accuracy: 0.9670 - val_loss: 0.2633 - val_accuracy: 0.9071
# Epoch 27/30
# 77/77 [==============================] - 965s 13s/step - loss: 0.0865 - accuracy: 0.9697 - val_loss: 0.2729 - val_accuracy: 0.8947
# Epoch 28/30
# 77/77 [==============================] - 962s 12s/step - loss: 0.0763 - accuracy: 0.9708 - val_loss: 0.2817 - val_accuracy: 0.9071
# Epoch 29/30
# 77/77 [==============================] - 963s 13s/step - loss: 0.0795 - accuracy: 0.9723 - val_loss: 0.2987 - val_accuracy: 0.8994
# Epoch 30/30
# 77/77 [==============================] - 961s 12s/step - loss: 0.0684 - accuracy: 0.9758 - val_loss: 0.2629 - val_accuracy: 0.9056

# %% [markdown]
# ### Evaluation:

# %%
model4.evaluate(train_aug)
# Out:
# 78/78 [==============================] - 146s 2s/step - loss: 0.0452 - accuracy: 0.9860
# [0.04519461840391159, 0.9859688878059387]

# %%
model4.evaluate(val_aug)
# Out:
# 20/20 [==============================] - 33s 2s/step - loss: 0.3066 - accuracy: 0.9121
# [0.3065687119960785, 0.9121212363243103]

# %% [markdown]
# #### Plotting Accuracy vs. Loss:

# %%
model_performance(hist)

# %% [markdown]
# This model is able to achieve a validation accuracy level of **91.2%** which is rather decent over 30 epochs. This is our best model yet and so I will save it:

# %%
#Saving the model
model4.save('model4.h5')

# %% [markdown]
# # Conclusion
# This project has shown how to benign and malignant diagnosis' from a set of skin lesion images and although it's far from perfect and could be improved, it is amazing to see the success of deep learning being used in real world problems.
#
# # Recommended Next Steps
# Re-run the models on the full dataset. I've originally done so, however give that the size of the file is so huge (4.18gb, over 25gb with augmentation), I was only able to run one model every few days (each model produced similar results as the ones aboe) and my kernel kept crashing, ultimately leaving me to keep restarting. However, now that I've completed this notebook I am able to simple update the dataset and rerun!
#
# Re-run some of the models with a greater number of epochs (such as 100 or more on the ones with 30) if necessary to determine if there is convergence. I've attempted this, however my system couldn't handle it.
#
# Fine tune and test other parameters to reduce overfitting as well as build a model with FN/FP/TN/TP metrics to get a more accurate look when the classes are imbalanced. (18)
#
# With this project as a base, our work can be built upon to detect more complex problems, such as determining the types of cancers, skin diseases related to Agent Orange and more.
#
# Output the model to a user friendly application, preferably a web app.

# %% [markdown]
# # References:

# %% [markdown]
# (1) https://docs.hashicorp.com/sentinel/imports/decimal
#
# (2) https://www.geeksforgeeks.org/convert-bgr-and-rgb-with-python-opencv/
#
# (3) https://datascience.stackexchange.com/questions/41921/sparse-categorical-crossentropy-vs-categorical-crossentropy-keras-accuracy
#
# (4) https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
#
# (5) https://pythonguides.com/python-print-2-decimal-places/#:~:text=Python%20print%202%20decimal%20places%20In%20Python%2C%20to,will%20print%20the%20float%20with%202%20decimal%20places.
#
# **EfficientNetB0:**
#
# https://keras.io/api/applications/efficientnet/
#
# https://paperswithcode.com/method/efficientnet
#
#
# (6) https://developers.google.com/machine-learning/crash-course/regularization-for-simplicity/l2-regularization
#
# (7) Thank you @python_wizard, @py_lenn, and @synthphreak from reddit for guiding me with this piece of code!
#
# (8) https://keras.io/api/callbacks/
#
# (9) https://keras.io/api/callbacks/reduce_lr_on_plateau/
#
# (10) https://keras.io/api/callbacks/model_checkpoint/
#
# (11) https://keras.io/api/callbacks/early_stopping
#
# (12) https://stackoverflow.com/questions/61362426/why-is-my-val-accuracy-stagnant-at-0-0000e00-while-my-val-loss-is-increasing-fr
#
# (13) https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a
#
# (14) https://stats.stackexchange.com/questions/260505/should-i-use-a-categorical-cross-entropy-or-binary-cross-entropy-loss-for-binary#:~:text=Binary%20cross-entropy%20is%20for%20multi-label%20classifications%2C%20whereas%20categorical,Thanks%20for%20contributing%20an%20answer%20to%20Cross%20Validated%21
#
# (15) https://keras.io/api/layers/convolution_layers/separable_convolution2d/
#
# (15A) https://towardsdatascience.com/a-basic-introduction-to-separable-convolutions-b99ec3102728
#
# **ResNet50:**
#
# (16) https://iq.opengenus.org/resnet50-architecture/
#
# (17) https://medium.com/@venkinarayanan/tutorial-image-classifier-using-resnet50-deep-learning-model-python-flask-in-azure-4c2b129af6d2
#
# (18) https://keras.io/examples/structured_data/imbalanced_classification/
#
# **VGG16:**
#
# (19) https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c
